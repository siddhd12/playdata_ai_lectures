# %% [markdown]
# # [YOLOv8](https://docs.ultralytics.com/)
#
# ## 설치
#
# 1. 파이토치 설치
# 2. YOLOv8 설치
#     - `pip install ultralytics`
# 3. 주피터노트북에서 실행할 경우 프로그래스바를 실행하기 위해서 다음을 설치한다. (필수는 아님)
#     - `conda install -y -c conda-forge ipywidgets`

# %% [markdown]
# ## 사용
# - CLI (command line interface)에서 터미널 명령어로 추론/평가/학습을 진행할 수 있다.
# - Python lib 를 이용해 코드상에 원하는 추론/평가/학습을 진행할 수 있다.

# %% [markdown]
# # CLI 기본 명령어 구조
#
# - 구문
#     - <span style='font-size:1.3em'>**yolo**  **task**=detect|classify|segment|pose  **mode**=train|val|predict  **model**=yolov8n.yaml|yolov8n.pt|..  **args**</span>
#     - <b style='font-size:1.2em'>task:</b> \[detect, classify, segment\] 중 하나를 지정한다. \[optional\]로 생략하면 model을 보고 추측해서 task를 정한다.
#         - **detect:** Object detection
#         - **classify:** Image classification
#         - **segment:** Instance segmentation
#     - <b style='font-size:1.2em'>mode:</b> \[train, val, predict, export\] 중 하나를 지정한다. \[필수\]로 입력해야 한다.
#         - **train:** custom dataset을 train 시킨다.
#         - **val:** 모델 성능을 평가한다.
#         - **predict:** 입력 이미지에 대한 추론을 한다.
#         - **export:** 모델을 다른 형식으로 변환한다.
#     - <b style='font-size:1.2em'>model:</b> **pretrained 모델**이나 **모델 설정 yaml 파일**의 경로를 설정한다. \[필수\]로 입력해야 한다.
#         - pretrained 모델 파일경로
#             - task에 맞는 pretrained 모델파일의 저장 경로를 지정한다.
#             - transfer learnging을 하거나 fine tuning 시 방법
#         - 모델 구조 설정 yaml 파일 경로
#             - task에 맞는 pretrained 모델 설정파일(yaml파일)의 경로를 지정한다.
#             - train mode에서 지정하며 모델을 새로 생성해서 처음부터 학습 시킬 경우 지정한다.
#         - Ultralytics에서 제공하는 Pretrained 모델
#             - 모델 크기에 따라 5개의 모델을 제공하며 큰 모델은 작은 모델에 비해 추론 성능이 좋은대신 속도는 느리다.
#             - 모델은 처음 추론또는 학습할때 local 컴퓨터에 없으면 download 받는다.
#             - https://github.com/ultralytics/ultralytics#models
#             - ### 제공 모델 - 없으면 다운받음
#
#             | **task\모델크기**           | **nano** | **small_** | **medium** | **large** | **xlarge** |
#             |:--------------------|----------|-------------|------------|-----------|----------|
#             | **detection**      | yolov8n  | yolov8s     | yolov8m    | yolov8l   | yolov8x    |
#             | **segmentation**   | yolov8n-seg  | yolov8s-seg     | yolov8m-seg    | yolov8l-seg   | yolov8x-seg    |
#             | **classification** | yolov8n-cls  | yolov8s-cls     | yolov8m-cls    | yolov8l-cls   | yolov8x-cls    |
#             | **pose estimation** | yolov8n-pose  | yolov8s-pose     | yolov8m-pose    | yolov8l-pose   | yolov8x-pose    |
#
#             - 확장자가 `pt`이면 pretrained 된 모델을, `yaml`이면 모델 구조 설정파일을 download하여 실행한다.
#                 - pretrained model은 fine tuning이나 추론할 때, yaml설정파일은 처음부터 학습할 경우 설정하여 받는다.
#     - <b style='font-size:1.2em'>args:</b> task와 mode과 관련한 추가 설정값들을 지정한다.
#         - https://docs.ultralytics.com/cfg/

# %% [markdown]
# # [Object Detection](https://docs.ultralytics.com/tasks/detection/)

# %% [markdown]
# ##  Predict (추론)
#
# ### 모델로딩
# - Ultralytics에서 제공하는 Pretrained Model이나 직접 학습시킨 모델을 이용해 추론한다.
# - Ultralytics는 Object Detection을 위한 [Pretrained 모델](#제공-모델)을 제공한다.
#     - Object Detection 모델은 COCO dataset으로 학습되었다.
#     - 모델 명을 지정하면 자동으로 다운로드를 받는다.

# %% [markdown]
# ### CLI
# `yolo task=detect mode=predict model=model_path source=추론할_image_path`
# - 추가 설정 (configuration)
#     - https://docs.ultralytics.com/cfg

# %%
# !pip install ultralytics --upgrade

# %%
# !yolo  task=detect  mode=predict   model=models/yolov8n.pt   source=test_image/3.jpg  save=True  save_txt=True  line_width=1
# Out:
# Downloading https:\github.com\ultralytics\assets\releases\download\v0.0.0\yolov8n.pt to models\yolov8n.pt...
#
#   0%|          | 0.00/6.23M [00:00<?, ?B/s]
#  24%|##3       | 1.48M/6.23M [00:00<00:00, 15.4MB/s]
#  80%|#######9  | 4.97M/6.23M [00:00<00:00, 26.6MB/s]
# 100%|##########| 6.23M/6.23M [00:00<00:00, 27.2MB/s]
# Ultralytics YOLOv8.0.117  Python-3.10.11 torch-2.0.1+cpu CPU
# YOLOv8n summary (fused): 168 layers, 3151904 parameters, 0 gradients
#
# image 1/1 C:\Users\Playdata\Desktop\deepLearning\Object_Detection\test_image\3.jpg: 448x640 1 cup, 1 chair, 1 tv, 1 mouse, 1 keyboard, 2 cell phones, 1 vase, 125.8ms
# Speed: 1.0ms preprocess, 125.8ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# Results saved to runs\detect\predict6
# 1 label saved to runs\detect\predict6\labels

# %% [markdown]
# ### Python

# %%
from ultralytics import YOLO

# %%
model = YOLO("models/yolov8m.pt")  # YOLO 클래스 객체 생성하면서 사용할 pretrained model의 경로를 지정.
# Out:
# Downloading https:\github.com\ultralytics\assets\releases\download\v0.0.0\yolov8m.pt to models\yolov8m.pt...
# 100%|█████████████████████████████████████████████████████████████████████████████| 49.7M/49.7M [00:02<00:00, 18.7MB/s]

# %%
model?

# %%
image_path = 'test_image/2.jpg'
result_list = model(image_path, save=True, save_txt=True, line_width=1)
# Out:
# image 1/1 C:\Users\Playdata\Desktop\deepLearning\Object_Detection\test_image\2.jpg: 448x640 12 persons, 5 cars, 1 motorcycle, 5 buss, 1 train, 1 truck, 6 traffic lights, 1 umbrella, 661.5ms
# Speed: 3.0ms preprocess, 661.5ms inference, 4.0ms postprocess per image at shape (1, 3, 640, 640)
# Results saved to runs\detect\predict7
# 1 label saved to runs\detect\predict7\labels

# %%
type(result_list), len(result_list)
# 리스트에 추론한 결과를 추론한 이미지별로 저장해서 반환.
# Out:
# (list, 1)

# %%
type(result_list[0])
# Out:
# ultralytics.yolo.engine.results.Results

# %% [markdown]
# ### 한번에 여러장 추론
# - 추론할 파일경로를 리스트로 묶어서 추론한다.

# %%
from glob import glob
file_path = glob('test_image/*.jpg')
file_path
# Out:
# ['test_image\\1.jpg',
#  'test_image\\2.jpg',
#  'test_image\\3.jpg',
#  'test_image\\4.jpg',
#  'test_image\\5.jpg',
#  'test_image\\6.jpg',
#  'test_image\\bus.jpg',
#  'test_image\\mara.jpg']

# %%
model = YOLO('models/yolov8m.pt')
result_list = model(file_path, save=True, save_txt=True, line_width=1)
# Out:
# 0: 640x640 7 persons, 3 bicycles, 5 cars, 1 motorcycle, 1 bus, 3 traffic lights, 1 dog, 1 backpack, 2 handbags, 1: 640x640 13 persons, 5 cars, 1 motorcycle, 5 buss, 1 truck, 6 traffic lights, 1 umbrella, 2: 640x640 1 car, 2 chairs, 1 tv, 1 mouse, 1 keyboard, 2 cell phones, 1 vase, 3: 640x640 3 elephants, 1 zebra, 4: 640x640 9 persons, 1 tie, 1 bottle, 16 wine glasss, 4 cups, 3 forks, 1 knife, 1 bowl, 1 potted plant, 2 dining tables, 5: 640x640 4 persons, 2 cups, 1 fork, 1 knife, 3 pizzas, 3 dining tables, 6: 640x640 4 persons, 1 bus, 7: 640x640 14 persons, 6743.1ms
# Speed: 6.9ms preprocess, 842.9ms inference, 2.4ms postprocess per image at shape (1, 3, 640, 640)
# Results saved to runs\detect\predict8
# 8 labels saved to runs\detect\predict8\labels

# %%
len(result_list), type(result_list[0])
# Out:
# (8, ultralytics.yolo.engine.results.Results)

# %% [markdown]
# ### web 상의 이미지 추론

# %%
result_list = model("https://ultralytics.com/images/bus.jpg", save=True)
# Out:
# Downloading https:\ultralytics.com\images\bus.jpg to bus.jpg...
# 100%|███████████████████████████████████████████████████████████████████████████████| 476k/476k [00:00<00:00, 22.6MB/s]
# image 1/1 C:\Users\Playdata\Desktop\deepLearning\Object_Detection\bus.jpg: 640x480 4 persons, 1 bus, 697.7ms
# Speed: 3.0ms preprocess, 697.7ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
# Results saved to runs\detect\predict8
# 8 labels saved to runs\detect\predict8\labels

# %%
result_list = model('https://storage3.ilyo.co.kr/contents/article/images/2015/0601/1433148424953500.jpg', save=True)
# Out:
# Downloading https:\storage3.ilyo.co.kr\contents\article\images\2015\0601\1433148424953500.jpg to 1433148424953500.jpg...
# 100%|███████████████████████████████████████████████████████████████████████████████| 228k/228k [00:00<00:00, 11.6MB/s]
# image 1/1 C:\Users\Playdata\Desktop\deepLearning\Object_Detection\1433148424953500.jpg: 448x640 12 persons, 2 elephants, 1 backpack, 554.4ms
# Speed: 3.1ms preprocess, 554.4ms inference, 2.6ms postprocess per image at shape (1, 3, 640, 640)
# Results saved to runs\detect\predict8
# 9 labels saved to runs\detect\predict8\labels

# %% [markdown]
# ## 추론결과

# %% [markdown]
# ### ultralytics.yolo.engine.results.Results
# - 모델의 추론 결과는 list에 이미지별 예측결과를 Results에 담아 반환한다.
# - **Results** : 한개 이미지에 대한 추론결과를 담는 객체
# - 추론 종류에 따라 다음 속성을 이용해 결과를 조회한다.
#     - Detection: `result.boxes` - Boxes type
#     - Segmentation: `result.masks` - Masks type
#     - Classification: `result.probs` - torch.Tensor type
#     - Pose: `result.keypoints` - Keypoints type
# - 추가 정보
#     - Results.orig_img: 추론한 원본 이미지
#     - Results.orig_shape: 추론한 원본 이미지의 크기 (height, width)
#     - Results.path: 추론한 원본이미지의 경로

# %%
from ultralytics import YOLO

model = YOLO('models/yolov8n.pt')
result_list = model('bus.jpg', save=True)
# Out:
# image 1/1 C:\Users\Playdata\Desktop\deepLearning\Object_Detection\bus.jpg: 640x480 4 persons, 1 bus, 1 stop sign, 165.2ms
# Speed: 2.0ms preprocess, 165.2ms inference, 4.0ms postprocess per image at shape (1, 3, 640, 640)
# Results saved to runs\detect\predict9

# %%
type(result_list), len(result_list), type(result_list[0])
# Out:
# (list, 1, ultralytics.yolo.engine.results.Results)

# %%
# 추론한 원본 이미지에 대한 정보
result = result_list[0]
print('원본 이미지 경로:', result.path)
print('원본 이미지 크기:', result.orig_shape)
print('원본 이미지:', result.orig_img.shape)
# Out:
# 원본 이미지 경로: C:\Users\Playdata\Desktop\deepLearning\Object_Detection\bus.jpg
# 원본 이미지 크기: (1080, 810)
# 원본 이미지: (1080, 810, 3)

# %% [markdown]
# ### Object Detection 결과값 조회
#
# - ultralytics.yolo.engine.results.**Boxes**에 추론 결과를 담아 반환
#     - Results.boxes로 조회
# - 주요 속성
#     - shape: 결과 shape. (찾은 물체개수, 6)
#     - boxes
#         - 6: 좌상단 x, 좌상단 y, 우하단 x, 우하단 y, confidence score, label
#     - xyxy
#         - bounding box의 `좌상단 x, 좌상단 y, 우하단 x, 우하단 y` 좌표 반환
#     - xyxyn
#         - xyxy를 이미지 대비 비율로 반환
#     - xywh
#         - bounding box의 `center x, center y, 너비, 높이` 를 반환
#     - xywhn
#         - xywh를 이미지 대비 비율로 반환
#     - cls: 찾은 물체의 label
#     - conf: cls에 대한 confidence score (그 물체일 확률)
#     - boxes
#         - `x, y, x, y, conf, cls` tensor를 반환

# %%
boxes = result.boxes  # detection한 결과를 조회 (Boxes 객체)
print(type(boxes))
# Out:
# <class 'ultralytics.yolo.engine.results.Boxes'>

# %%
boxes.shape
# [n, 6] : n-찾은 bbox(object) 개수,  6-x y x y label conf  (x y x y : 좌상단 우하단 좌표)
# Out:
# torch.Size([6, 6])

# %%
# 찾은 bbox들에 대한 classification 정보
print(boxes.cls)  # 찾은 n개 bbox에 대한 class 들을 반환.
print(boxes.conf) # 찾은 n개 bbox에대한 confidence score(확률) 들을 반환
# Out:
# tensor([ 5.,  0.,  0.,  0., 11.,  0.])
# tensor([0.8705, 0.8690, 0.8536, 0.8193, 0.3461, 0.3013])

# %%
# bbox의 위치정보
print(boxes.xyxy)  # 좌상단 우하단 x/y좌표
print(boxes.xyxyn) #이미지크기 대비 비율
# Out:
# tensor([[1.7286e+01, 2.3059e+02, 8.0152e+02, 7.6841e+02],
#         [4.8739e+01, 3.9926e+02, 2.4450e+02, 9.0250e+02],
#         [6.7027e+02, 3.8028e+02, 8.0986e+02, 8.7569e+02],
#         [2.2139e+02, 4.0579e+02, 3.4472e+02, 8.5739e+02],
#         [6.4354e-02, 2.5464e+02, 3.2288e+01, 3.2504e+02],
#         [0.0000e+00, 5.5101e+02, 6.7105e+01, 8.7394e+02]])
# tensor([[2.1340e-02, 2.1351e-01, 9.8953e-01, 7.1149e-01],
#         [6.0172e-02, 3.6969e-01, 3.0185e-01, 8.3565e-01],
#         [8.2749e-01, 3.5211e-01, 9.9982e-01, 8.1082e-01],
#         [2.7333e-01, 3.7573e-01, 4.2558e-01, 7.9388e-01],
#         [7.9449e-05, 2.3578e-01, 3.9862e-02, 3.0096e-01],
#         [0.0000e+00, 5.1019e-01, 8.2846e-02, 8.0920e-01]])

# %%
print(boxes.xywh)  # center x, y좌표, bbox width, height
print(boxes.xywhn)  # center x, y좌표, bbox width, height 이미지크기 대비 비율
# Out:
# tensor([[409.4020, 499.4990, 784.2324, 537.8137],
#         [146.6206, 650.8826, 195.7623, 503.2372],
#         [740.0637, 627.9874, 139.5888, 495.4068],
#         [283.0555, 631.5919, 123.3235, 451.6003],
#         [ 16.1764, 289.8419,  32.2241,  70.3949],
#         [ 33.5525, 712.4718,  67.1050, 322.9278]])
# tensor([[0.5054, 0.4625, 0.9682, 0.4980],
#         [0.1810, 0.6027, 0.2417, 0.4660],
#         [0.9137, 0.5815, 0.1723, 0.4587],
#         [0.3495, 0.5848, 0.1523, 0.4181],
#         [0.0200, 0.2684, 0.0398, 0.0652],
#         [0.0414, 0.6597, 0.0828, 0.2990]])

# %%
from module import util

print(util.get_color(0))
print(util.get_coco80_classname(0)) # 문자열로 리턴
print(util.get_imagenet_classname(1)) # index주면 해당 클래스이름 알려줌
# Out:
# (205, 92, 92)
# person
# goldfish, Carassius auratus

# %%
idx = boxes.cls[1]
idx
# Out:
# tensor(0.)

# %%
util.get_coco80_classname(int(idx.item()))
# Out:
# 'person'

# %%
# 원본 이미지에 추론 결과를 출력
import cv2
from ultralytics import YOLO

model = YOLO('models/yolov8m.pt')
path = 'bus.jpg'
path = 'test_image/1.jpg'
result_list = model(path, save=True)
result = result_list[0]

org_img = result.orig_img  #BGR
img = org_img.copy()

boxes = result.boxes
xyxy_list = boxes.xyxy  #좌상단/우하단 좌표
cls_list = boxes.cls    #label
conf_list = boxes.conf  #label  확률.
for xyxy, cls, conf in zip(xyxy_list, cls_list, conf_list):
#     print(xyxy, conf, cls)
    xyxy_arr = xyxy.to('cpu').numpy().astype('int32')
    pt1 = xyxy_arr[:2]
    pt2 = xyxy_arr[2:]
    
    label_name = util.get_coco80_classname(int(cls.item()))
    txt = f"{label_name}-{conf.item()*100:.2f}"
    
    color = util.get_color(int(cls.item()) % 10)
    # bbox
    cv2.rectangle(img, pt1=pt1, pt2=pt2, color=color, thickness=2)
    # label
    cv2.putText(img, text=txt, org=pt1-5, fontFace=cv2.FONT_HERSHEY_SIMPLEX, fontScale=0.5, 
                color=color, thickness=1, lineType=cv2.LINE_AA)
# Out:
# image 1/1 C:\Users\Playdata\Desktop\deepLearning\Object_Detection\test_image\1.jpg: 480x640 8 persons, 2 bicycles, 5 cars, 1 motorcycle, 2 buss, 3 traffic lights, 1 dog, 1 backpack, 2 handbags, 648.4ms
# Speed: 3.1ms preprocess, 648.4ms inference, 3.2ms postprocess per image at shape (1, 3, 640, 640)
# Results saved to runs\detect\predict10

# %%
cv2.imshow('frame', img)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %% [markdown]
# ## 실시간 Detection

# %%
import cv2
from module import util
from ultralytics import YOLO

# 웹캠 연동
cap = cv2.VideoCapture(0)
# 모델 생성
model = YOLO('models/yolov8n.pt')
while True:
    # 한 Frame 읽기
    success, frame = cap.read()
    if not success:
        print('프레임을 읽지 못함')
        break
        
    frame = cv2.cvtColor(cv2.flip(frame, 1), cv2.COLOR_BGR2RGB)
    
    result = model(frame)[0]
    xyxy_list = result.boxes.xyxy.to('cpu').numpy().astype('int32')
    cls_list = result.boxes.cls.to('cpu').numpy().astype('int32')
    conf_list = result.boxes.conf.to('cpu').numpy()
    
    for xyxy, cls, conf in zip(xyxy_list, cls_list, conf_list):
        pt1, pt2 = xyxy[:2], xyxy[2:]
        txt = f"{util.get_coco80_classname(cls)}-{conf*100:.2f}%"
        color = util.get_color(cls % 10)
        cv2.rectangle(frame, pt1, pt2, color=color)
        cv2.putText(frame, txt, org=pt1, fontFace=cv2.FONT_HERSHEY_SIMPLEX, fontScale=1,
                    color=color, thickness=2, lineType=cv2.LINE_AA)
        
    # 화면에 출력
    cv2.imshow('frame', cv2.cvtColor(frame, cv2.COLOR_BGR2RGB))
    if cv2.waitKey(1) == 27: # esc 
        break
        
cv2.destroyAllWindows()
cap.release()
# Out:
# 0: 480x640 (no detections), 208.4ms
# Speed: 2.9ms preprocess, 208.4ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 480x640 (no detections), 117.2ms
# Speed: 1.0ms preprocess, 117.2ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 480x640 (no detections), 118.5ms
# Speed: 4.3ms preprocess, 118.5ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 480x640 (no detections), 112.9ms
# Speed: 2.1ms preprocess, 112.9ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 480x640 (no detections), 116.2ms
# Speed: 2.0ms preprocess, 116.2ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 480x640 (no detections), 97.7ms
# Speed: 4.2ms preprocess, 97.7ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 480x640 (no detections), 133.7ms
# Speed: 1.0ms preprocess, 133.7ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 480x640 (no detections), 113.8ms
# Speed: 4.3ms preprocess, 113.8ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 480x640 (no detections), 105.4ms
# Speed: 2.6ms preprocess, 105.4ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 480x640 (no detections), 113.8ms
# Speed: 4.0ms preprocess, 113.8ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 480x640 (no detections), 119.3ms
# Speed: 2.6ms preprocess, 119.3ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 480x640 (no detections), 118.8ms
# Speed: 1.8ms preprocess, 118.8ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 480x640 (no detections), 102.3ms
# Speed: 2.0ms preprocess, 102.3ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 480x640 (no detections), 113.8ms
# Speed: 2.0ms preprocess, 113.8ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 480x640 (no detections), 130.8ms
# Speed: 3.4ms preprocess, 130.8ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 480x640 (no detections), 109.9ms
# Speed: 3.9ms preprocess, 109.9ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 480x640 (no detections), 118.6ms
# Speed: 2.0ms preprocess, 118.6ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 480x640 (no detections), 110.6ms
# Speed: 12.0ms preprocess, 110.6ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 480x640 (no detections), 106.6ms
# Speed: 3.1ms preprocess, 106.6ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 480x640 (no detections), 109.8ms
# Speed: 2.7ms preprocess, 109.8ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 480x640 (no detections), 117.4ms
# Speed: 1.6ms preprocess, 117.4ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 480x640 (no detections), 123.0ms
# Speed: 1.7ms preprocess, 123.0ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 480x640 (no detections), 121.4ms
# Speed: 2.0ms preprocess, 121.4ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 480x640 (no detections), 108.6ms
# Speed: 2.3ms preprocess, 108.6ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 480x640 (no detections), 114.9ms
# Speed: 3.7ms preprocess, 114.9ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 480x640 (no detections), 125.5ms
# Speed: 3.2ms preprocess, 125.5ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 480x640 (no detections), 126.6ms
# Speed: 2.7ms preprocess, 126.6ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 480x640 (no detections), 98.2ms
# Speed: 3.5ms preprocess, 98.2ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 480x640 (no detections), 142.5ms
# Speed: 1.7ms preprocess, 142.5ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 480x640 (no detections), 122.1ms
# Speed: 2.9ms preprocess, 122.1ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 480x640 (no detections), 120.9ms
# Speed: 2.6ms preprocess, 120.9ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 480x640 (no detections), 122.9ms
# Speed: 4.2ms preprocess, 122.9ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 480x640 (no detections), 116.9ms
# Speed: 5.4ms preprocess, 116.9ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 480x640 (no detections), 113.5ms
# Speed: 2.0ms preprocess, 113.5ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 480x640 (no detections), 122.5ms
# Speed: 3.0ms preprocess, 122.5ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 480x640 (no detections), 110.0ms
# Speed: 2.5ms preprocess, 110.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 480x640 (no detections), 114.3ms
# Speed: 2.4ms preprocess, 114.3ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 480x640 (no detections), 102.4ms
# Speed: 1.0ms preprocess, 102.4ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 480x640 (no detections), 117.3ms
# Speed: 2.0ms preprocess, 117.3ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 480x640 (no detections), 124.7ms
# Speed: 2.0ms preprocess, 124.7ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 480x640 (no detections), 118.0ms
# Speed: 1.0ms preprocess, 118.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 480x640 (no detections), 116.6ms
# Speed: 1.9ms preprocess, 116.6ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 480x640 (no detections), 102.5ms
# Speed: 2.5ms preprocess, 102.5ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 480x640 (no detections), 125.3ms
# Speed: 1.9ms preprocess, 125.3ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 480x640 (no detections), 107.6ms
# Speed: 1.0ms preprocess, 107.6ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 480x640 (no detections), 115.7ms
# Speed: 1.8ms preprocess, 115.7ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 480x640 (no detections), 121.1ms
# Speed: 2.0ms preprocess, 121.1ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 480x640 (no detections), 105.7ms
# Speed: 1.0ms preprocess, 105.7ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 480x640 (no detections), 117.7ms
# Speed: 1.0ms preprocess, 117.7ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 480x640 (no detections), 95.0ms
# Speed: 2.0ms preprocess, 95.0ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 480x640 (no detections), 99.6ms
# Speed: 2.0ms preprocess, 99.6ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 480x640 (no detections), 101.3ms
# Speed: 2.0ms preprocess, 101.3ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 480x640 (no detections), 115.8ms
# Speed: 2.0ms preprocess, 115.8ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 480x640 (no detections), 107.3ms
# Speed: 2.6ms preprocess, 107.3ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 480x640 (no detections), 111.3ms
# Speed: 1.3ms preprocess, 111.3ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 480x640 (no detections), 107.6ms
# Speed: 1.6ms preprocess, 107.6ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 480x640 (no detections), 101.9ms
# Speed: 1.0ms preprocess, 101.9ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 480x640 (no detections), 116.2ms
# Speed: 2.0ms preprocess, 116.2ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 480x640 (no detections), 125.1ms
# Speed: 1.6ms preprocess, 125.1ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 480x640 (no detections), 95.2ms
# Speed: 1.0ms preprocess, 95.2ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 480x640 (no detections), 115.4ms
# Speed: 1.0ms preprocess, 115.4ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# 0: 480x640 (no detections), 129.4ms
# Speed: 2.0ms preprocess, 129.4ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 480x640 (no detections), 117.5ms
# Speed: 1.6ms preprocess, 117.5ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 480x640 (no detections), 118.2ms
# Speed: 6.2ms preprocess, 118.2ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 480x640 (no detections), 120.2ms
# Speed: 2.0ms preprocess, 120.2ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 480x640 (no detections), 126.5ms
# Speed: 2.6ms preprocess, 126.5ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 480x640 (no detections), 115.0ms
# Speed: 2.1ms preprocess, 115.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 480x640 (no detections), 133.6ms
# Speed: 1.0ms preprocess, 133.6ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 480x640 (no detections), 117.8ms
# Speed: 1.0ms preprocess, 117.8ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 480x640 (no detections), 124.4ms
# Speed: 1.7ms preprocess, 124.4ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 480x640 (no detections), 143.2ms
# Speed: 1.0ms preprocess, 143.2ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 480x640 (no detections), 98.3ms
# Speed: 2.0ms preprocess, 98.3ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 480x640 (no detections), 101.4ms
# Speed: 1.0ms preprocess, 101.4ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 480x640 (no detections), 126.0ms
# Speed: 2.0ms preprocess, 126.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 480x640 (no detections), 129.6ms
# Speed: 2.2ms preprocess, 129.6ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 480x640 (no detections), 121.5ms
# Speed: 1.0ms preprocess, 121.5ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 480x640 (no detections), 130.7ms
# Speed: 0.8ms preprocess, 130.7ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 480x640 (no detections), 111.4ms
# Speed: 1.8ms preprocess, 111.4ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 480x640 (no detections), 117.6ms
# Speed: 2.5ms preprocess, 117.6ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 480x640 (no detections), 103.5ms
# Speed: 2.0ms preprocess, 103.5ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 480x640 (no detections), 102.9ms
# Speed: 1.0ms preprocess, 102.9ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 480x640 (no detections), 136.0ms
# Speed: 2.1ms preprocess, 136.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 480x640 (no detections), 103.3ms
# Speed: 1.0ms preprocess, 103.3ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 480x640 (no detections), 101.9ms
# Speed: 2.0ms preprocess, 101.9ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 480x640 2 persons, 115.8ms
# Speed: 2.5ms preprocess, 115.8ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 480x640 1 person, 120.3ms
# Speed: 1.5ms preprocess, 120.3ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 480x640 1 dog, 118.9ms
# Speed: 1.5ms preprocess, 118.9ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 480x640 1 person, 115.8ms
# Speed: 2.2ms preprocess, 115.8ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 480x640 1 person, 99.5ms
# Speed: 2.0ms preprocess, 99.5ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 480x640 1 dog, 105.3ms
# Speed: 1.0ms preprocess, 105.3ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 480x640 1 person, 97.0ms
# Speed: 2.3ms preprocess, 97.0ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 480x640 (no detections), 133.2ms
# Speed: 2.0ms preprocess, 133.2ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 480x640 (no detections), 118.8ms
# Speed: 3.2ms preprocess, 118.8ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 480x640 2 persons, 131.2ms
# Speed: 2.5ms preprocess, 131.2ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 480x640 2 persons, 97.5ms
# Speed: 1.9ms preprocess, 97.5ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 480x640 2 persons, 106.2ms
# Speed: 2.0ms preprocess, 106.2ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 480x640 1 person, 136.4ms
# Speed: 2.0ms preprocess, 136.4ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 480x640 1 person, 108.6ms
# Speed: 2.0ms preprocess, 108.6ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 480x640 1 person, 116.8ms
# Speed: 1.0ms preprocess, 116.8ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 480x640 1 person, 1 laptop, 129.4ms
# Speed: 2.0ms preprocess, 129.4ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 480x640 1 person, 1 laptop, 111.4ms
# Speed: 2.5ms preprocess, 111.4ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 480x640 1 person, 1 laptop, 140.4ms
# Speed: 1.5ms preprocess, 140.4ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 480x640 1 person, 1 laptop, 106.9ms
# Speed: 1.0ms preprocess, 106.9ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 480x640 1 person, 1 laptop, 120.7ms
# Speed: 1.0ms preprocess, 120.7ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 480x640 1 person, 1 laptop, 120.0ms
# Speed: 1.5ms preprocess, 120.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 480x640 1 person, 1 laptop, 116.7ms
# Speed: 2.0ms preprocess, 116.7ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 480x640 1 person, 1 laptop, 114.0ms
# Speed: 0.5ms preprocess, 114.0ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 480x640 1 person, 1 laptop, 107.0ms
# Speed: 1.5ms preprocess, 107.0ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 480x640 1 person, 1 laptop, 108.7ms
# Speed: 2.1ms preprocess, 108.7ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 480x640 1 person, 1 laptop, 111.5ms
# Speed: 2.0ms preprocess, 111.5ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 480x640 1 person, 1 laptop, 99.6ms
# Speed: 1.7ms preprocess, 99.6ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 480x640 1 person, 1 laptop, 111.2ms
# Speed: 2.0ms preprocess, 111.2ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 480x640 1 person, 1 laptop, 142.0ms
# Speed: 1.0ms preprocess, 142.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 480x640 1 person, 1 laptop, 103.0ms
# Speed: 2.0ms preprocess, 103.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 480x640 1 person, 1 laptop, 112.4ms
# Speed: 2.0ms preprocess, 112.4ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 480x640 1 person, 1 tv, 1 laptop, 116.7ms
# Speed: 1.0ms preprocess, 116.7ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 480x640 1 person, 1 laptop, 120.5ms
# Speed: 2.0ms preprocess, 120.5ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 480x640 1 person, 1 laptop, 117.8ms
# Speed: 2.0ms preprocess, 117.8ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 480x640 1 person, 1 laptop, 102.3ms
# Speed: 3.1ms preprocess, 102.3ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 480x640 1 person, 1 tv, 1 laptop, 107.5ms
# Speed: 1.0ms preprocess, 107.5ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 480x640 1 person, 1 laptop, 121.2ms
# Speed: 1.0ms preprocess, 121.2ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 480x640 1 person, 1 tv, 101.5ms
# Speed: 2.0ms preprocess, 101.5ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 640)
# 0: 480x640 1 person, 1 tv, 1 laptop, 129.9ms
# Speed: 2.0ms preprocess, 129.9ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 480x640 1 person, 122.8ms
# Speed: 1.5ms preprocess, 122.8ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 480x640 1 person, 1 tv, 113.6ms
# Speed: 1.0ms preprocess, 113.6ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 480x640 1 person, 1 laptop, 117.5ms
# Speed: 1.5ms preprocess, 117.5ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 480x640 1 person, 1 laptop, 116.6ms
# Speed: 2.0ms preprocess, 116.6ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 480x640 1 person, 1 laptop, 109.5ms
# Speed: 2.0ms preprocess, 109.5ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 480x640 1 person, 1 laptop, 115.2ms
# Speed: 2.0ms preprocess, 115.2ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 480x640 1 person, 1 tv, 1 laptop, 116.1ms
# Speed: 1.3ms preprocess, 116.1ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 480x640 1 person, 108.3ms
# Speed: 2.1ms preprocess, 108.3ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 480x640 1 person, 124.1ms
# Speed: 2.1ms preprocess, 124.1ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 480x640 1 person, 1 laptop, 113.6ms
# Speed: 2.0ms preprocess, 113.6ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 480x640 1 person, 1 laptop, 99.8ms
# Speed: 3.2ms preprocess, 99.8ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 480x640 1 person, 1 dog, 1 laptop, 101.2ms
# Speed: 2.0ms preprocess, 101.2ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 480x640 1 person, 1 laptop, 126.8ms
# Speed: 2.0ms preprocess, 126.8ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 480x640 1 dog, 1 laptop, 93.8ms
# Speed: 2.1ms preprocess, 93.8ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 480x640 1 dog, 1 tv, 135.0ms
# Speed: 2.0ms preprocess, 135.0ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 480x640 1 dog, 1 tv, 1 laptop, 120.8ms
# Speed: 1.0ms preprocess, 120.8ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 480x640 1 person, 1 dog, 1 tv, 114.1ms
# Speed: 2.0ms preprocess, 114.1ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 480x640 2 persons, 1 dog, 1 laptop, 118.1ms
# Speed: 2.1ms preprocess, 118.1ms inference, 3.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 480x640 2 persons, 1 laptop, 115.0ms
# Speed: 2.0ms preprocess, 115.0ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 480x640 1 person, 1 laptop, 126.8ms
# Speed: 2.0ms preprocess, 126.8ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 480x640 2 persons, 1 laptop, 118.7ms
# Speed: 2.1ms preprocess, 118.7ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 480x640 2 persons, 1 laptop, 104.9ms
# Speed: 1.8ms preprocess, 104.9ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 480x640 2 persons, 1 laptop, 103.3ms
# Speed: 2.7ms preprocess, 103.3ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 480x640 3 persons, 1 laptop, 135.1ms
# Speed: 2.4ms preprocess, 135.1ms inference, 2.5ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 480x640 2 persons, 1 tv, 1 laptop, 107.7ms
# Speed: 2.1ms preprocess, 107.7ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 480x640 4 persons, 1 laptop, 105.0ms
# Speed: 2.9ms preprocess, 105.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 480x640 2 persons, 1 tv, 1 laptop, 105.6ms
# Speed: 2.0ms preprocess, 105.6ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 480x640 2 persons, 1 laptop, 135.0ms
# Speed: 2.1ms preprocess, 135.0ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 480x640 2 persons, 1 tv, 108.1ms
# Speed: 1.0ms preprocess, 108.1ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 480x640 1 dog, 1 tv, 120.5ms
# Speed: 1.0ms preprocess, 120.5ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 480x640 1 person, 1 dog, 1 laptop, 127.4ms
# Speed: 2.0ms preprocess, 127.4ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 480x640 1 person, 1 dog, 1 tv, 1 laptop, 128.7ms
# Speed: 1.0ms preprocess, 128.7ms inference, 2.5ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 480x640 1 person, 1 dog, 1 tv, 105.5ms
# Speed: 2.0ms preprocess, 105.5ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 480x640 1 person, 1 dog, 106.5ms
# Speed: 1.5ms preprocess, 106.5ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 480x640 1 dog, 1 tv, 118.4ms
# Speed: 1.5ms preprocess, 118.4ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 480x640 1 dog, 1 laptop, 98.3ms
# Speed: 2.0ms preprocess, 98.3ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 480x640 1 dog, 1 laptop, 95.0ms
# Speed: 2.0ms preprocess, 95.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 480x640 2 dogs, 1 tv, 110.5ms
# Speed: 2.0ms preprocess, 110.5ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 480x640 1 person, 1 dog, 94.6ms
# Speed: 1.0ms preprocess, 94.6ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 480x640 1 person, 1 dog, 1 tv, 114.4ms
# Speed: 1.0ms preprocess, 114.4ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 480x640 1 dog, 120.4ms
# Speed: 2.0ms preprocess, 120.4ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 480x640 1 dog, 1 tv, 1 laptop, 145.9ms
# Speed: 1.6ms preprocess, 145.9ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 480x640 1 dog, 1 tv, 101.8ms
# Speed: 0.5ms preprocess, 101.8ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 480x640 1 dog, 1 laptop, 131.5ms
# Speed: 1.0ms preprocess, 131.5ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 480x640 2 dogs, 1 laptop, 127.4ms
# Speed: 2.0ms preprocess, 127.4ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 480x640 2 dogs, 1 tv, 1 laptop, 91.9ms
# Speed: 1.0ms preprocess, 91.9ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 480x640 1 dog, 124.0ms
# Speed: 2.0ms preprocess, 124.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 480x640 1 person, 1 dog, 106.7ms
# Speed: 2.0ms preprocess, 106.7ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 480x640 1 dog, 112.6ms
# Speed: 2.0ms preprocess, 112.6ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 480x640 1 person, 1 dog, 138.8ms
# Speed: 1.0ms preprocess, 138.8ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 480x640 1 person, 1 dog, 135.2ms
# Speed: 2.0ms preprocess, 135.2ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 480x640 1 person, 1 dog, 117.1ms
# Speed: 2.0ms preprocess, 117.1ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 480x640 1 person, 1 dog, 1 laptop, 111.2ms
# Speed: 1.0ms preprocess, 111.2ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 480x640 2 persons, 1 dog, 1 tv, 1 laptop, 112.3ms
# Speed: 2.0ms preprocess, 112.3ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 480x640 1 person, 1 dog, 1 laptop, 103.1ms
# Speed: 2.0ms preprocess, 103.1ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 480x640 (no detections), 106.0ms
# Speed: 2.0ms preprocess, 106.0ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 480x640 1 cat, 1 dog, 115.2ms
# Speed: 2.0ms preprocess, 115.2ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 480x640 1 person, 1 cat, 1 dog, 115.6ms
# Speed: 1.0ms preprocess, 115.6ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 480x640 1 person, 1 cat, 1 dog, 112.2ms
# Speed: 1.0ms preprocess, 112.2ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# 0: 480x640 1 cat, 1 dog, 121.1ms
# Speed: 1.0ms preprocess, 121.1ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 480x640 2 persons, 1 cat, 1 dog, 106.0ms
# Speed: 2.0ms preprocess, 106.0ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 480x640 1 person, 1 cat, 2 dogs, 1 tv, 1 laptop, 120.5ms
# Speed: 2.0ms preprocess, 120.5ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 480x640 1 cat, 1 dog, 1 laptop, 125.4ms
# Speed: 2.0ms preprocess, 125.4ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 480x640 1 person, 1 tv, 1 laptop, 117.7ms
# Speed: 2.3ms preprocess, 117.7ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 480x640 1 cat, 1 laptop, 115.0ms
# Speed: 2.0ms preprocess, 115.0ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 480x640 1 cat, 1 laptop, 95.6ms
# Speed: 2.0ms preprocess, 95.6ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 480x640 1 cat, 1 laptop, 109.8ms
# Speed: 2.1ms preprocess, 109.8ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 480x640 1 tv, 1 laptop, 114.2ms
# Speed: 2.0ms preprocess, 114.2ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 480x640 1 tv, 1 laptop, 114.2ms
# Speed: 4.6ms preprocess, 114.2ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 480x640 1 tv, 1 laptop, 120.1ms
# Speed: 1.5ms preprocess, 120.1ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 480x640 1 dog, 1 tv, 1 laptop, 126.7ms
# Speed: 2.0ms preprocess, 126.7ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 480x640 1 person, 1 cat, 1 tv, 1 laptop, 109.2ms
# Speed: 3.5ms preprocess, 109.2ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 480x640 1 person, 1 laptop, 113.8ms
# Speed: 3.3ms preprocess, 113.8ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 480x640 1 cat, 1 dog, 1 tv, 136.6ms
# Speed: 1.0ms preprocess, 136.6ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 480x640 1 cat, 130.5ms
# Speed: 2.0ms preprocess, 130.5ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 480x640 1 cat, 1 laptop, 99.8ms
# Speed: 2.0ms preprocess, 99.8ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 480x640 1 person, 1 dog, 1 laptop, 117.1ms
# Speed: 2.0ms preprocess, 117.1ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 480x640 1 dog, 1 tv, 1 laptop, 99.8ms
# Speed: 1.0ms preprocess, 99.8ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 480x640 1 dog, 1 laptop, 110.5ms
# Speed: 2.2ms preprocess, 110.5ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 480x640 1 dog, 103.9ms
# Speed: 3.0ms preprocess, 103.9ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 480x640 1 cat, 1 dog, 116.3ms
# Speed: 2.0ms preprocess, 116.3ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 480x640 1 person, 117.1ms
# Speed: 1.5ms preprocess, 117.1ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 480x640 3 persons, 97.7ms
# Speed: 2.0ms preprocess, 97.7ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 480x640 2 persons, 1 tv, 123.3ms
# Speed: 1.5ms preprocess, 123.3ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 480x640 2 persons, 1 tv, 1 laptop, 132.5ms
# Speed: 2.1ms preprocess, 132.5ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 480x640 2 persons, 1 tv, 1 laptop, 133.1ms
# Speed: 2.0ms preprocess, 133.1ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 480x640 1 person, 1 tv, 123.4ms
# Speed: 5.6ms preprocess, 123.4ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 480x640 1 person, 1 tv, 128.6ms
# Speed: 1.9ms preprocess, 128.6ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 480x640 2 persons, 121.3ms
# Speed: 1.0ms preprocess, 121.3ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 480x640 4 persons, 124.3ms
# Speed: 1.0ms preprocess, 124.3ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 480x640 2 persons, 126.6ms
# Speed: 1.0ms preprocess, 126.6ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 480x640 2 persons, 115.7ms
# Speed: 1.1ms preprocess, 115.7ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 480x640 2 persons, 107.8ms
# Speed: 1.0ms preprocess, 107.8ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 480x640 2 persons, 1 laptop, 128.3ms
# Speed: 1.0ms preprocess, 128.3ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 480x640 2 persons, 1 tv, 1 laptop, 129.6ms
# Speed: 1.0ms preprocess, 129.6ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 480x640 2 persons, 1 tv, 1 laptop, 129.4ms
# Speed: 1.0ms preprocess, 129.4ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 480x640 2 persons, 1 tv, 111.1ms
# Speed: 2.0ms preprocess, 111.1ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 480x640 2 persons, 1 tv, 1 laptop, 118.3ms
# Speed: 1.0ms preprocess, 118.3ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 480x640 1 person, 1 tv, 1 laptop, 114.0ms
# Speed: 1.0ms preprocess, 114.0ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 480x640 2 persons, 1 tv, 1 laptop, 116.3ms
# Speed: 1.6ms preprocess, 116.3ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 480x640 2 persons, 1 tv, 132.8ms
# Speed: 2.3ms preprocess, 132.8ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 480x640 2 persons, 1 tv, 1 laptop, 107.9ms
# Speed: 1.0ms preprocess, 107.9ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 480x640 1 person, 1 tv, 1 laptop, 129.0ms
# Speed: 2.5ms preprocess, 129.0ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 480x640 1 person, 1 laptop, 105.3ms
# Speed: 2.3ms preprocess, 105.3ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 480x640 1 person, 1 tv, 1 laptop, 113.8ms
# Speed: 2.0ms preprocess, 113.8ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 480x640 1 person, 1 tv, 1 laptop, 112.1ms
# Speed: 1.0ms preprocess, 112.1ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 480x640 1 person, 1 tv, 1 laptop, 138.2ms
# Speed: 2.0ms preprocess, 138.2ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 480x640 1 person, 1 laptop, 103.0ms
# Speed: 2.0ms preprocess, 103.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 480x640 1 person, 1 laptop, 101.4ms
# Speed: 1.0ms preprocess, 101.4ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 480x640 1 person, 1 tv, 1 laptop, 112.6ms
# Speed: 1.9ms preprocess, 112.6ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 480x640 2 persons, 1 laptop, 106.1ms
# Speed: 2.0ms preprocess, 106.1ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 480x640 2 persons, 1 laptop, 129.5ms
# Speed: 1.0ms preprocess, 129.5ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 480x640 2 persons, 1 laptop, 121.5ms
# Speed: 2.4ms preprocess, 121.5ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 480x640 1 person, 1 tv, 1 laptop, 117.3ms
# Speed: 1.4ms preprocess, 117.3ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 480x640 1 person, 1 laptop, 112.5ms
# Speed: 1.6ms preprocess, 112.5ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 480x640 1 person, 1 bench, 1 dog, 1 laptop, 121.4ms
# Speed: 1.5ms preprocess, 121.4ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 480x640 1 person, 1 dog, 1 laptop, 109.0ms
# Speed: 1.0ms preprocess, 109.0ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 480x640 1 person, 1 laptop, 108.7ms
# Speed: 3.0ms preprocess, 108.7ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 480x640 1 person, 1 laptop, 119.8ms
# Speed: 1.9ms preprocess, 119.8ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 480x640 1 person, 113.4ms
# Speed: 1.8ms preprocess, 113.4ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 480x640 1 person, 102.7ms
# Speed: 1.0ms preprocess, 102.7ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 480x640 1 person, 115.2ms
# Speed: 2.0ms preprocess, 115.2ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 480x640 1 person, 125.6ms
# Speed: 2.5ms preprocess, 125.6ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 480x640 1 person, 100.5ms
# Speed: 2.0ms preprocess, 100.5ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 480x640 1 person, 123.1ms
# Speed: 1.5ms preprocess, 123.1ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 480x640 1 person, 115.8ms
# Speed: 2.0ms preprocess, 115.8ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 480x640 1 person, 97.9ms
# Speed: 2.7ms preprocess, 97.9ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 480x640 1 person, 121.7ms
# Speed: 2.0ms preprocess, 121.7ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 480x640 1 person, 1 bird, 128.1ms
# Speed: 2.0ms preprocess, 128.1ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 480x640 1 person, 132.7ms
# Speed: 1.6ms preprocess, 132.7ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 480x640 2 persons, 152.3ms
# Speed: 2.1ms preprocess, 152.3ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 480x640 2 persons, 112.1ms
# Speed: 1.0ms preprocess, 112.1ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 480x640 2 persons, 101.3ms
# Speed: 2.0ms preprocess, 101.3ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 480x640 1 person, 108.0ms
# Speed: 2.0ms preprocess, 108.0ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 480x640 1 person, 106.2ms
# Speed: 1.3ms preprocess, 106.2ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 480x640 1 person, 134.2ms
# Speed: 1.0ms preprocess, 134.2ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 480x640 1 person, 117.3ms
# Speed: 2.0ms preprocess, 117.3ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 480x640 1 person, 1 chair, 1 laptop, 128.0ms
# Speed: 1.8ms preprocess, 128.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 480x640 1 person, 120.6ms
# Speed: 2.0ms preprocess, 120.6ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 480x640 1 person, 1 laptop, 124.7ms
# Speed: 2.0ms preprocess, 124.7ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 480x640 1 person, 1 laptop, 109.5ms
# Speed: 1.0ms preprocess, 109.5ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 480x640 1 person, 1 laptop, 121.5ms
# Speed: 2.6ms preprocess, 121.5ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 480x640 1 person, 1 laptop, 150.9ms
# Speed: 2.1ms preprocess, 150.9ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 480x640 1 person, 1 laptop, 111.6ms
# Speed: 1.3ms preprocess, 111.6ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 480x640 1 person, 1 laptop, 106.1ms
# Speed: 2.0ms preprocess, 106.1ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 480x640 1 person, 1 laptop, 136.1ms
# Speed: 2.0ms preprocess, 136.1ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 480x640 1 person, 1 laptop, 102.0ms
# Speed: 2.0ms preprocess, 102.0ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 480x640 1 person, 1 laptop, 106.8ms
# Speed: 1.0ms preprocess, 106.8ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 480x640 1 person, 1 laptop, 114.6ms
# Speed: 1.0ms preprocess, 114.6ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 480x640 1 person, 1 laptop, 109.7ms
# Speed: 2.0ms preprocess, 109.7ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 480x640 1 person, 1 laptop, 118.9ms
# Speed: 2.0ms preprocess, 118.9ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 480x640 1 person, 1 laptop, 121.4ms
# Speed: 1.0ms preprocess, 121.4ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 480x640 1 person, 1 laptop, 108.9ms
# Speed: 1.0ms preprocess, 108.9ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 480x640 1 person, 1 laptop, 119.3ms
# Speed: 1.0ms preprocess, 119.3ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 480x640 1 person, 1 laptop, 118.5ms
# Speed: 1.0ms preprocess, 118.5ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 480x640 1 person, 1 laptop, 158.1ms
# Speed: 1.0ms preprocess, 158.1ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 480x640 1 person, 1 tv, 1 laptop, 115.7ms
# Speed: 2.6ms preprocess, 115.7ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 480x640 1 person, 1 laptop, 130.4ms
# Speed: 2.0ms preprocess, 130.4ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 480x640 1 person, 1 laptop, 120.4ms
# Speed: 2.0ms preprocess, 120.4ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 480x640 1 person, 1 laptop, 116.0ms
# Speed: 1.9ms preprocess, 116.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 480x640 1 person, 1 tv, 1 laptop, 124.4ms
# Speed: 1.3ms preprocess, 124.4ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 480x640 1 person, 1 laptop, 113.1ms
# Speed: 2.1ms preprocess, 113.1ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 480x640 1 person, 1 laptop, 124.0ms
# Speed: 2.0ms preprocess, 124.0ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 480x640 1 person, 1 tv, 130.5ms
# Speed: 2.0ms preprocess, 130.5ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 480x640 1 person, 1 tv, 1 laptop, 116.5ms
# Speed: 2.3ms preprocess, 116.5ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 480x640 1 person, 1 laptop, 130.6ms
# Speed: 1.5ms preprocess, 130.6ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 480x640 1 person, 1 tv, 101.0ms
# Speed: 2.0ms preprocess, 101.0ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 480x640 1 person, 1 tv, 1 laptop, 114.6ms
# Speed: 2.0ms preprocess, 114.6ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 480x640 1 person, 1 laptop, 112.6ms
# Speed: 2.2ms preprocess, 112.6ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 480x640 2 persons, 115.7ms
# Speed: 2.0ms preprocess, 115.7ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 480x640 2 persons, 132.8ms
# Speed: 1.0ms preprocess, 132.8ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 480x640 3 persons, 110.0ms
# Speed: 1.0ms preprocess, 110.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 480x640 2 persons, 1 laptop, 118.6ms
# Speed: 2.0ms preprocess, 118.6ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 480x640 2 persons, 1 laptop, 111.2ms
# Speed: 3.0ms preprocess, 111.2ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 480x640 1 person, 2 dogs, 1 laptop, 97.8ms
# Speed: 2.0ms preprocess, 97.8ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 480x640 1 person, 1 dog, 1 laptop, 123.1ms
# Speed: 2.5ms preprocess, 123.1ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 480x640 1 person, 1 dog, 1 laptop, 117.2ms
# Speed: 1.0ms preprocess, 117.2ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 480x640 3 persons, 1 laptop, 117.0ms
# Speed: 2.0ms preprocess, 117.0ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 480x640 3 persons, 1 bird, 1 tv, 1 laptop, 119.3ms
# Speed: 2.1ms preprocess, 119.3ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
# 0: 480x640 2 persons, 1 dog, 1 tv, 1 laptop, 115.8ms
# Speed: 2.3ms preprocess, 115.8ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 480x640 3 persons, 1 laptop, 111.3ms
# Speed: 2.0ms preprocess, 111.3ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 480x640 2 persons, 1 dog, 118.5ms
# Speed: 2.0ms preprocess, 118.5ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 480x640 4 persons, 1 dog, 104.6ms
# Speed: 1.0ms preprocess, 104.6ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 480x640 2 persons, 1 dog, 108.3ms
# Speed: 2.0ms preprocess, 108.3ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 480x640 2 persons, 1 cat, 119.5ms
# Speed: 2.0ms preprocess, 119.5ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 480x640 2 persons, 1 cat, 129.6ms
# Speed: 2.0ms preprocess, 129.6ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 480x640 2 persons, 1 oven, 118.4ms
# Speed: 2.0ms preprocess, 118.4ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 480x640 2 persons, 111.4ms
# Speed: 2.0ms preprocess, 111.4ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 480x640 1 person, 1 laptop, 112.9ms
# Speed: 2.6ms preprocess, 112.9ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 480x640 1 person, 1 dog, 1 laptop, 110.1ms
# Speed: 2.4ms preprocess, 110.1ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 480x640 1 person, 124.2ms
# Speed: 2.3ms preprocess, 124.2ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 480x640 1 person, 1 dog, 1 laptop, 118.6ms
# Speed: 2.0ms preprocess, 118.6ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 480x640 1 person, 1 laptop, 108.7ms
# Speed: 2.0ms preprocess, 108.7ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 480x640 1 person, 1 laptop, 119.7ms
# Speed: 1.5ms preprocess, 119.7ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 480x640 1 person, 1 laptop, 105.0ms
# Speed: 2.1ms preprocess, 105.0ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 480x640 1 person, 1 laptop, 106.5ms
# Speed: 1.4ms preprocess, 106.5ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 480x640 1 person, 1 laptop, 130.4ms
# Speed: 1.8ms preprocess, 130.4ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 480x640 1 person, 1 laptop, 106.3ms
# Speed: 2.0ms preprocess, 106.3ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 480x640 1 person, 1 laptop, 148.2ms
# Speed: 1.4ms preprocess, 148.2ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 480x640 1 person, 1 laptop, 129.5ms
# Speed: 2.0ms preprocess, 129.5ms inference, 2.6ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 480x640 1 person, 1 laptop, 121.0ms
# Speed: 2.0ms preprocess, 121.0ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 480x640 1 person, 1 tv, 1 laptop, 116.1ms
# Speed: 1.0ms preprocess, 116.1ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 480x640 1 person, 1 laptop, 107.7ms
# Speed: 2.0ms preprocess, 107.7ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 480x640 1 person, 1 tv, 1 laptop, 111.6ms
# Speed: 2.0ms preprocess, 111.6ms inference, 2.5ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 480x640 1 person, 1 tv, 1 laptop, 113.1ms
# Speed: 1.8ms preprocess, 113.1ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 480x640 1 person, 1 laptop, 112.0ms
# Speed: 2.0ms preprocess, 112.0ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 480x640 1 person, 1 laptop, 113.0ms
# Speed: 17.2ms preprocess, 113.0ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 480x640 1 person, 1 tv, 116.1ms
# Speed: 1.0ms preprocess, 116.1ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 480x640 1 person, 1 tv, 1 laptop, 125.8ms
# Speed: 2.0ms preprocess, 125.8ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 480x640 1 person, 1 tv, 1 laptop, 119.7ms
# Speed: 2.3ms preprocess, 119.7ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 480x640 1 person, 1 laptop, 119.6ms
# Speed: 2.0ms preprocess, 119.6ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 480x640 1 person, 1 tv, 1 laptop, 110.7ms
# Speed: 2.0ms preprocess, 110.7ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 480x640 1 person, 110.2ms
# Speed: 1.9ms preprocess, 110.2ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 480x640 1 person, 1 tv, 1 laptop, 109.8ms
# Speed: 2.0ms preprocess, 109.8ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 480x640 1 person, 1 tv, 108.3ms
# Speed: 1.0ms preprocess, 108.3ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 480x640 1 person, 1 tv, 1 laptop, 123.1ms
# Speed: 2.0ms preprocess, 123.1ms inference, 3.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 480x640 1 person, 1 tv, 1 laptop, 133.5ms
# Speed: 2.0ms preprocess, 133.5ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 480x640 1 person, 1 laptop, 115.3ms
# Speed: 2.0ms preprocess, 115.3ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 480x640 1 person, 1 laptop, 118.9ms
# Speed: 2.0ms preprocess, 118.9ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 480x640 1 person, 1 laptop, 114.8ms
# Speed: 1.0ms preprocess, 114.8ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 480x640 1 person, 1 laptop, 117.1ms
# Speed: 2.0ms preprocess, 117.1ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 480x640 1 person, 1 tv, 1 laptop, 117.2ms
# Speed: 2.0ms preprocess, 117.2ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 480x640 1 person, 1 tv, 1 laptop, 106.1ms
# Speed: 1.5ms preprocess, 106.1ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 480x640 1 person, 1 laptop, 115.0ms
# Speed: 1.0ms preprocess, 115.0ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 480x640 1 person, 1 laptop, 121.3ms
# Speed: 1.5ms preprocess, 121.3ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 480x640 1 person, 1 laptop, 110.3ms
# Speed: 2.0ms preprocess, 110.3ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 480x640 1 person, 1 tv, 1 laptop, 132.2ms
# Speed: 1.9ms preprocess, 132.2ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 480x640 1 person, 1 laptop, 110.1ms
# Speed: 1.0ms preprocess, 110.1ms inference, 3.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 480x640 1 person, 1 laptop, 104.7ms
# ...
#
# 0: 480x640 (no detections), 106.7ms
# Speed: 2.0ms preprocess, 106.7ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 480x640 (no detections), 113.6ms
# Speed: 1.5ms preprocess, 113.6ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 480x640 (no detections), 113.8ms
# Speed: 2.6ms preprocess, 113.8ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 480x640 (no detections), 122.4ms
# Speed: 2.2ms preprocess, 122.4ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 480x640 (no detections), 120.6ms
# Speed: 2.0ms preprocess, 120.6ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 480x640 (no detections), 124.8ms
# Speed: 2.7ms preprocess, 124.8ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# 0: 480x640 (no detections), 124.6ms
# Speed: 1.6ms preprocess, 124.6ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 480x640 (no detections), 134.8ms
# Speed: 3.4ms preprocess, 134.8ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 480x640 (no detections), 113.6ms
# Speed: 2.0ms preprocess, 113.6ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 480x640 (no detections), 114.3ms
# Speed: 2.0ms preprocess, 114.3ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 480x640 (no detections), 113.9ms
# Speed: 2.0ms preprocess, 113.9ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 480x640 (no detections), 112.5ms
# Speed: 1.0ms preprocess, 112.5ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 480x640 (no detections), 121.1ms
# Speed: 7.1ms preprocess, 121.1ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 480x640 (no detections), 120.0ms
# Speed: 1.6ms preprocess, 120.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 480x640 (no detections), 111.0ms
# Speed: 1.0ms preprocess, 111.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 480x640 (no detections), 116.3ms
# Speed: 2.0ms preprocess, 116.3ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 480x640 (no detections), 108.7ms
# Speed: 2.0ms preprocess, 108.7ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 480x640 (no detections), 113.9ms
# Speed: 2.0ms preprocess, 113.9ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 480x640 (no detections), 116.1ms
# Speed: 2.0ms preprocess, 116.1ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 480x640 (no detections), 127.0ms
# Speed: 3.0ms preprocess, 127.0ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 480x640 (no detections), 114.5ms
# Speed: 1.0ms preprocess, 114.5ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 480x640 (no detections), 129.8ms
# Speed: 2.0ms preprocess, 129.8ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 480x640 (no detections), 112.2ms
# Speed: 1.6ms preprocess, 112.2ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 480x640 (no detections), 119.5ms
# Speed: 5.0ms preprocess, 119.5ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 480x640 (no detections), 109.7ms
# Speed: 2.0ms preprocess, 109.7ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 480x640 (no detections), 116.8ms
# Speed: 2.3ms preprocess, 116.8ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 480x640 (no detections), 119.7ms
# Speed: 1.5ms preprocess, 119.7ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 480x640 (no detections), 131.1ms
# Speed: 2.5ms preprocess, 131.1ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 480x640 (no detections), 114.1ms
# Speed: 2.5ms preprocess, 114.1ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 480x640 (no detections), 112.9ms
# Speed: 1.5ms preprocess, 112.9ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 480x640 (no detections), 131.8ms
# Speed: 2.0ms preprocess, 131.8ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 480x640 (no detections), 107.1ms
# Speed: 2.2ms preprocess, 107.1ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 480x640 (no detections), 113.8ms
# Speed: 1.8ms preprocess, 113.8ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 480x640 (no detections), 115.3ms
# Speed: 1.0ms preprocess, 115.3ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 480x640 (no detections), 136.2ms
# Speed: 1.5ms preprocess, 136.2ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 480x640 (no detections), 120.1ms
# Speed: 1.9ms preprocess, 120.1ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 480x640 (no detections), 131.7ms
# Speed: 2.6ms preprocess, 131.7ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 480x640 (no detections), 115.5ms
# Speed: 2.5ms preprocess, 115.5ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 480x640 (no detections), 127.0ms
# Speed: 3.0ms preprocess, 127.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 480x640 (no detections), 107.6ms
# Speed: 2.6ms preprocess, 107.6ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 480x640 (no detections), 106.9ms
# Speed: 2.0ms preprocess, 106.9ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 480x640 (no detections), 115.3ms
# Speed: 2.0ms preprocess, 115.3ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 480x640 (no detections), 127.4ms
# Speed: 2.5ms preprocess, 127.4ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 480x640 (no detections), 128.1ms
# Speed: 2.5ms preprocess, 128.1ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 480x640 (no detections), 124.0ms
# Speed: 2.0ms preprocess, 124.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 480x640 (no detections), 117.2ms
# Speed: 1.7ms preprocess, 117.2ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 480x640 (no detections), 117.8ms
# Speed: 2.0ms preprocess, 117.8ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 480x640 (no detections), 116.1ms
# Speed: 2.5ms preprocess, 116.1ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 480x640 (no detections), 119.0ms
# Speed: 1.2ms preprocess, 119.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 480x640 (no detections), 126.2ms
# Speed: 2.5ms preprocess, 126.2ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 480x640 (no detections), 129.3ms
# Speed: 2.1ms preprocess, 129.3ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 480x640 (no detections), 99.8ms
# Speed: 2.8ms preprocess, 99.8ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 480x640 (no detections), 116.2ms
# Speed: 1.6ms preprocess, 116.2ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 480x640 (no detections), 121.8ms
# Speed: 2.0ms preprocess, 121.8ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 480x640 (no detections), 117.6ms
# Speed: 2.5ms preprocess, 117.6ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 480x640 (no detections), 117.4ms
# Speed: 2.0ms preprocess, 117.4ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 480x640 (no detections), 110.7ms
# Speed: 2.7ms preprocess, 110.7ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 480x640 (no detections), 132.6ms
# Speed: 1.0ms preprocess, 132.6ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 480x640 (no detections), 125.4ms
# Speed: 2.7ms preprocess, 125.4ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 480x640 (no detections), 106.8ms
# Speed: 2.0ms preprocess, 106.8ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 480x640 (no detections), 122.5ms
# Speed: 3.4ms preprocess, 122.5ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 480x640 (no detections), 118.0ms
# Speed: 2.0ms preprocess, 118.0ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 480x640 (no detections), 117.9ms
# Speed: 2.0ms preprocess, 117.9ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 480x640 (no detections), 119.0ms
# Speed: 2.0ms preprocess, 119.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 480x640 (no detections), 106.7ms
# Speed: 2.0ms preprocess, 106.7ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 480x640 (no detections), 123.8ms
# Speed: 1.6ms preprocess, 123.8ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 480x640 (no detections), 127.5ms
# Speed: 3.0ms preprocess, 127.5ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# 0: 480x640 (no detections), 112.0ms
# Speed: 2.9ms preprocess, 112.0ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 480x640 (no detections), 122.8ms
# Speed: 2.0ms preprocess, 122.8ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 480x640 (no detections), 109.6ms
# Speed: 2.0ms preprocess, 109.6ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 480x640 (no detections), 118.5ms
# Speed: 1.5ms preprocess, 118.5ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 480x640 (no detections), 130.1ms
# Speed: 2.0ms preprocess, 130.1ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 480x640 (no detections), 116.6ms
# Speed: 2.0ms preprocess, 116.6ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 480x640 (no detections), 119.7ms
# Speed: 1.0ms preprocess, 119.7ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 480x640 (no detections), 120.2ms
# Speed: 2.0ms preprocess, 120.2ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 480x640 (no detections), 111.9ms
# Speed: 2.0ms preprocess, 111.9ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 480x640 (no detections), 111.0ms
# Speed: 3.5ms preprocess, 111.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 480x640 (no detections), 114.7ms
# Speed: 1.0ms preprocess, 114.7ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 480x640 (no detections), 120.8ms
# Speed: 1.6ms preprocess, 120.8ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 480x640 (no detections), 113.6ms
# Speed: 2.3ms preprocess, 113.6ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 480x640 (no detections), 145.9ms
# Speed: 1.0ms preprocess, 145.9ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 480x640 (no detections), 125.6ms
# Speed: 2.5ms preprocess, 125.6ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 480x640 (no detections), 100.7ms
# Speed: 1.1ms preprocess, 100.7ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 480x640 (no detections), 121.5ms
# Speed: 1.5ms preprocess, 121.5ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 480x640 (no detections), 112.0ms
# Speed: 1.5ms preprocess, 112.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 480x640 (no detections), 105.8ms
# Speed: 2.0ms preprocess, 105.8ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 480x640 (no detections), 111.0ms
# Speed: 2.0ms preprocess, 111.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 480x640 (no detections), 112.2ms
# Speed: 2.0ms preprocess, 112.2ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 480x640 (no detections), 122.9ms
# Speed: 2.2ms preprocess, 122.9ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 480x640 (no detections), 115.9ms
# Speed: 1.0ms preprocess, 115.9ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 480x640 (no detections), 117.9ms
# Speed: 1.6ms preprocess, 117.9ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 480x640 (no detections), 115.5ms
# Speed: 2.7ms preprocess, 115.5ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 480x640 (no detections), 111.3ms
# Speed: 1.5ms preprocess, 111.3ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 480x640 (no detections), 116.8ms
# Speed: 2.2ms preprocess, 116.8ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 480x640 (no detections), 122.2ms
# Speed: 2.7ms preprocess, 122.2ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 480x640 (no detections), 112.3ms
# Speed: 3.2ms preprocess, 112.3ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 480x640 (no detections), 130.0ms
# Speed: 0.9ms preprocess, 130.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 480x640 (no detections), 103.4ms
# Speed: 2.5ms preprocess, 103.4ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 480x640 (no detections), 117.3ms
# Speed: 2.0ms preprocess, 117.3ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 480x640 (no detections), 117.8ms
# Speed: 2.6ms preprocess, 117.8ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 480x640 (no detections), 118.2ms
# Speed: 1.0ms preprocess, 118.2ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 480x640 (no detections), 107.8ms
# Speed: 4.1ms preprocess, 107.8ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 480x640 (no detections), 127.1ms
# Speed: 2.2ms preprocess, 127.1ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 480x640 (no detections), 120.7ms
# Speed: 1.0ms preprocess, 120.7ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 480x640 (no detections), 144.9ms
# Speed: 2.5ms preprocess, 144.9ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 480x640 (no detections), 122.8ms
# Speed: 3.2ms preprocess, 122.8ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 480x640 (no detections), 121.4ms
# Speed: 2.1ms preprocess, 121.4ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 480x640 (no detections), 117.3ms
# Speed: 2.7ms preprocess, 117.3ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 480x640 (no detections), 125.5ms
# Speed: 2.1ms preprocess, 125.5ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 480x640 (no detections), 110.5ms
# Speed: 2.0ms preprocess, 110.5ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 480x640 (no detections), 120.6ms
# Speed: 2.5ms preprocess, 120.6ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 480x640 (no detections), 124.9ms
# Speed: 3.0ms preprocess, 124.9ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 480x640 (no detections), 110.0ms
# Speed: 2.4ms preprocess, 110.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 480x640 (no detections), 126.4ms
# Speed: 2.5ms preprocess, 126.4ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 480x640 (no detections), 107.8ms
# Speed: 1.0ms preprocess, 107.8ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 480x640 (no detections), 121.1ms
# Speed: 2.2ms preprocess, 121.1ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 480x640 (no detections), 101.9ms
# Speed: 1.4ms preprocess, 101.9ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 480x640 (no detections), 134.5ms
# Speed: 3.3ms preprocess, 134.5ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
