# %% [raw]
# # 정렬
# ## index이름, column 이름을 기준으로 정렬
#
# - <b style='font-size:1.2em'>sort_index(axis, ascending=True)</b>
#     - axis
#         - index 이름 기준 정렬(행) : 'index' 또는 0 (기본값)
#         - column 이름 기준 정렬(열) : 'columns' 또는 1
#     - ascending
#         - 정렬방식
#         - True(기본): 오름차순, False: 내림차순
#     - inplace
#         - 원본에 적용 여부
#         - False(기본): 변경한 복사본 반환
#         - True : 원본을 변경

# %%
import pandas as pd
df = pd.read_csv("data/movie.csv",index_col="movie_title") # index를 colummns 'movie_title' 로 지정하가고 csv를 읽겠다
df.head()
# Out:
#                                             color      director_name
# movie_title
# Avatar                                      Color      James Cameron  \
# Pirates of the Caribbean: At World's End    Color     Gore Verbinski
# Spectre                                     Color         Sam Mendes
# The Dark Knight Rises                       Color  Christopher Nolan
# Star Wars: Episode VII - The Force Awakens    NaN        Doug Walker
#
#                                             num_critic_for_reviews  duration
# movie_title
# Avatar                                                       723.0     178.0  \
# Pirates of the Caribbean: At World's End                     302.0     169.0
# Spectre                                                      602.0     148.0
# The Dark Knight Rises                                        813.0     164.0
# Star Wars: Episode VII - The Force Awakens                     NaN       NaN
#
# ...

# %%
# 행 - index name 기준정렬
result =df.sort_index() # 오름차순 -> 원본을 바꾸지 않음
result.head() #
# Out:
#                             color        director_name
# movie_title
# #Horror                     Color         Tara Subkoff  \
# 10 Cloverfield Lane         Color     Dan Trachtenberg
# 10 Days in a Madhouse       Color        Timothy Hines
# 10 Things I Hate About You  Color           Gil Junger
# 10,000 B.C.                   NaN  Christopher Barnard
#
#                             num_critic_for_reviews  duration
# movie_title
# #Horror                                       35.0     101.0  \
# 10 Cloverfield Lane                          411.0     104.0
# 10 Days in a Madhouse                          1.0     111.0
# 10 Things I Hate About You                   133.0      97.0
# 10,000 B.C.                                    NaN      22.0
#
#                             director_facebook_likes  actor_3_facebook_likes
# movie_title
# #Horror                                        37.0                    56.0  \
# ...

# %%
result = df.sort_index(ascending=False) # 내림차순
result.head()
# Out:
#                          color     director_name  num_critic_for_reviews
# movie_title
# Æon Flux                 Color      Karyn Kusama                   178.0  \
# xXx: State of the Union  Color      Lee Tamahori                    77.0
# xXx                      Color         Rob Cohen                   191.0
# eXistenZ                 Color  David Cronenberg                   196.0
# [Rec] 2                  Color   Jaume Balagueró                   222.0
#
#                          duration  director_facebook_likes
# movie_title
# Æon Flux                     93.0                     45.0  \
# xXx: State of the Union     101.0                     93.0
# xXx                         132.0                    357.0
# eXistenZ                    115.0                      0.0
# [Rec] 2                      85.0                     57.0
#
#                          actor_3_facebook_likes    actor_2_name
# movie_title
# ...

# %%
df.sort_index(axis='columns')#=1) # 컬럼 정렬
# Out:
#                                             actor_1_facebook_likes
# movie_title
# Avatar                                                      1000.0  \
# Pirates of the Caribbean: At World's End                   40000.0
# Spectre                                                    11000.0
# The Dark Knight Rises                                      27000.0
# Star Wars: Episode VII - The Force Awakens                   131.0
# ...                                                            ...
# Signed Sealed Delivered                                      637.0
# The Following                                                841.0
# A Plague So Pleasant                                           0.0
# Shanghai Calling                                             946.0
# My Date with Drew                                             86.0
#
#                                                actor_1_name
# movie_title
# Avatar                                          CCH Pounder  \
# ...

# %%
df.loc['A':'C'] # 부분일치로 slicing -> 기본적으로는 안됨
# index name이 정렬된 상태면 가능
df.loc["A":"C"]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\envs\ml\lib\site-packages\pandas\core\indexes\base.py:3652, in Index.get_loc(self, key)
#    3651 try:
# -> 3652     return self._engine.get_loc(casted_key)
#    3653 except KeyError as err:
#
# File ~\anaconda3\envs\ml\lib\site-packages\pandas\_libs\index.pyx:147, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~\anaconda3\envs\ml\lib\site-packages\pandas\_libs\index.pyx:176, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:7080, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'A'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ...

# %%
df.sort_index()["A":"c"]
# index name을 정렬하면 
## 1. 부분일치 slicing 가능
## 2 . loc indexer로 조화시 속도가 더 빨라짐
# Out:
#                                        color         director_name
# movie_title
# A Beautiful Mind                       Color            Ron Howard  \
# A Beginner's Guide to Snuff            Color      Mitchell Altieri
# A Better Life                          Color           Chris Weitz
# A Bridge Too Far             Black and White  Richard Attenborough
# A Bug's Life                           Color         John Lasseter
# ...                                      ...                   ...
# Zoolander 2                            Color           Ben Stiller
# Zoom                                   Color          Peter Hewitt
# Zulu                                   Color          Jérôme Salle
# [Rec]                                  Color       Jaume Balagueró
# [Rec] 2                                Color       Jaume Balagueró
#
#                              num_critic_for_reviews  duration
# movie_title
# A Beautiful Mind                              205.0     135.0  \
# ...

# %% [markdown]
# ## 특정 컬럼(열)의 값을 기준으로 정렬
# - <b style='font-size:1.2em'>sort_values(by, ascending, inplace)</b>
#     - by
#         - **정렬 기준 컬럼이름**을 문자열로 지정
#         - 여러 컬럼에 대해 정렬할 경우 리스트에 담아 전달
#     - ascending
#         - 정렬방식
#         - True(기본): 오름차순, False: 내림차순
#         - 여러 컬럼에 대해 정렬할 경우 정렬방식도 리스트에 담아 전달
#     - inplace
#         - 원본에 적용 여부
#         - False(기본): 변경한 복사본 반환
#         - True : 원본을 변경
#     - 결측치는 방식과 상관없이 마지막에 나온다.

# %%
df.sort_values("duration") # duration 컬럼 기준으로 오름차순 정렬
# Out:
#                                       color     director_name  \
# movie_title
# The Touch                             Color        Jane Clark
# Shaun the Sheep                       Color               NaN
# Robot Chicken                         Color               NaN
# Vessel                                Color       Clark Baker
# Wal-Mart: The High Cost of Low Price  Color  Robert Greenwald
# ...                                     ...               ...
# Wolf Creek                            Color               NaN
# Karachi se Lahore                     Color      Wajahat Rauf
# Destiny                               Color   Joseph Kosinski
# Romantic Schemer                      Color         Valentine
# The Naked Ape                         Color    Daniel Mellitz
#
#                                       num_critic_for_reviews  duration  \
# movie_title
# The Touch                                                NaN       7.0
# ...

# %%
df.sort_values("duration",ascending=False)  # 내림차순으로 조회
# Out:
#                           color        director_name  num_critic_for_reviews  \
# movie_title
# Trapped                   Color                  NaN                    16.0
# Carlos                    Color                  NaN                   108.0
# Blood In, Blood Out       Color      Taylor Hackford                    12.0
# Heaven's Gate             Color       Michael Cimino                   102.0
# The Legend of Suriyothai  Color  Chatrichalerm Yukol                    31.0
# ...                         ...                  ...                     ...
# Wolf Creek                Color                  NaN                     2.0
# Karachi se Lahore         Color         Wajahat Rauf                     6.0
# Destiny                   Color      Joseph Kosinski                     4.0
# Romantic Schemer          Color            Valentine                     NaN
# The Naked Ape             Color       Daniel Mellitz                     NaN
#
# ...

# %%
df.sort_values(['duration','imdb_score'])[["duration","imdb_score"]].head(30)
# 1차로 duration으로 구분하고 
# 2차로 duration이 값이 같을 경우 imdb_score로 두번째 정렬하겠다라는 의미 
# 예시 duration = 7 값이 두개면 7인 값에서 imdb_score로 정렬하겠다
# 방식: 둘다 기본방식--> 오름차순
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 df.sort_values(['duration','imdb_score'])[["duration","imdb_score"]].head(30)
#       2 # 1차로 duration으로 구분하고
#       3 # 2차로 duration이 값이 같을 경우 imdb_score로 두번째 정렬하겠다라는 의미
#       4 # 예시 duration = 7 값이 두개면 7인 값에서 imdb_score로 정렬하겠다
#       5 # 방식: 둘다 기본방식--> 오름차순
#
# NameError: name 'df' is not defined

# %%
df.sort_values(['duration','imdb_score'],ascending=[True,False])[["duration","imdb_score"]].head(10)
# duration: True
# imdb_score:False
# Out:
#                                       duration  imdb_score
# movie_title
# Shaun the Sheep                            7.0         8.3
# The Touch                                  7.0         5.2
# Robot Chicken                             11.0         7.8
# Vessel                                    14.0         6.2
# Wal-Mart: The High Cost of Low Price      20.0         6.8
# It's Always Sunny in Philadelphia         22.0         8.8
# Home Movies                               22.0         8.2
# Strangers with Candy                      22.0         8.1
# Rules of Engagement                       22.0         7.3
# 10,000 B.C.                               22.0         7.2

# %%
df.query("duration>=250").sort_values("duration")
# query로 duration 250 이상을 조회하고 조회한 컬럼의 값 duratiom으로 정렬해서 보겠다
 90 , 70 55  45 60
# Out:
#                              color         director_name  \
# movie_title
# Cleopatra                    Color  Joseph L. Mankiewicz
# Once Upon a Time in America  Color          Sergio Leone
# Arn: The Knight Templar      Color          Peter Flinth
# Gettysburg                   Color           Ron Maxwell
# Gods and Generals            Color           Ron Maxwell
# The Company                  Color                   NaN
# Apocalypse Now               Color  Francis Ford Coppola
# Das Boot                     Color     Wolfgang Petersen
# The Legend of Suriyothai     Color   Chatrichalerm Yukol
# Heaven's Gate                Color        Michael Cimino
# Blood In, Blood Out          Color       Taylor Hackford
# Carlos                       Color                   NaN
# Trapped                      Color                   NaN
#
#                              num_critic_for_reviews  duration  \
# movie_title
# Cleopatra                                      72.0     251.0
# ...

# %%
# Seriesrorcp.value_counts() 고유값(class값)의 개수
df['director_name'].value_counts().sort_values(ascending= True)
result=df['director_name'].value_counts().sort_values()
result[result>15] # 10편 이상의 영화가 등록된 감독
result[result>15].sort_index()7.plot(kind="bar")
# Out:
# <Axes: >

# %%
# 이산형(값의 범위가 정해져있는것 ) 범주형 ->문자열 ,정수
ex) A-B-O-AB  A와 B사이에 값이 없다 전부 구분되어 정해져있음 범주형
# 연속형(값의 범위에 무한대로 늘어나는 경우)
100~101 은 100.xxxxxxxxx1 ,100.xxxxxxxxxxxx2 이런식으로 수가 굉장히 많아질 수 있음

# %% [markdown]
# # flights.csv (항공기 운항 기록 데이터)
# - MONTH : 비행 월
# - DAY : 비행 일
# - WEEKDAY : 비행 요일 - 1(월요일)~7(일요일)
# - AIRLINE : 항공사 코드
#      - UA:	United Air Lines Inc.
#      - AA:	American Airlines Inc.
#      - US:	US Airways Inc.
#      - F9:	Frontier Airlines Inc.
#      - B6:	JetBlue Airways
#      - OO:	Skywest Airlines Inc.
#      - AS:	Alaska Airlines Inc.
#      - NK:	Spirit Air Lines
#      - WN:	Southwest Airlines Co.
#      - DL:	Delta Air Lines Inc.
#      - EV:	Atlantic Southeast Airlines
#      - HA:	Hawaiian Airlines Inc.
#      - MQ:	American Eagle Airlines Inc.
#      - VX:	Virgin America
# - ORG_AIR : 출발공항
# - DEST_AIR : 도착공항
# - SCHED_DEP : 출발예정시각
# - DEP_DELAY : 출발지연시간(분)
# - AIR_TIME : 비행시간(분)
# - DIST : 비행거리(마일)
# - SCHED_ARR : 도착예정시각
# - ARR_DELAY : 도착지연시간(분)
# - DIVERTED : 회항여부(1: True, 0: False)
# - CANCELLED : 취소여부(1: True, 0: False)

# %%
import pandas as pd
flights =pd.read_csv('data/flights.csv')
flights.head(19)
# Out:
#     MONTH  DAY  WEEKDAY AIRLINE ORG_AIR DEST_AIR  SCHED_DEP  DEP_DELAY
# 0       1    1        4      WN     LAX      SLC       1625       58.0  \
# 1       1    1        4      UA     DEN      IAD        823        7.0
# 2       1    1        4      MQ     DFW      VPS       1305       36.0
# 3       1    1        4      AA     DFW      DCA       1555        7.0
# 4       1    1        4      WN     LAX      MCI       1720       48.0
# 5       1    1        4      UA     IAH      SAN       1450        1.0
# 6       1    1        4      AA     DFW      MSY       1250       84.0
# 7       1    1        4      F9     SFO      PHX       1020       -7.0
# 8       1    1        4      AA     ORD      STL       1845       -5.0
# 9       1    1        4      UA     IAH      SJC        925        3.0
# 10      1    1        4      MQ     DFW      DRO       1335       28.0
# 11      1    1        4      EV     ORD      JAN       1155        6.0
# ...

# %%
flights.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 58492 entries, 0 to 58491
# Data columns (total 14 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   MONTH      58492 non-null  int64
#  1   DAY        58492 non-null  int64
#  2   WEEKDAY    58492 non-null  int64
#  3   AIRLINE    58492 non-null  object
#  4   ORG_AIR    58492 non-null  object
#  5   DEST_AIR   58492 non-null  object
#  6   SCHED_DEP  58492 non-null  int64
#  7   DEP_DELAY  57659 non-null  float64
#  8   AIR_TIME   57474 non-null  float64
#  9   DIST       58492 non-null  int64
#  10  SCHED_ARR  58492 non-null  int64
#  11  ARR_DELAY  57474 non-null  float64
#  12  DIVERTED   58492 non-null  int64
#  13  CANCELLED  58492 non-null  int64
# dtypes: float64(3), int64(8), object(3)
# memory usage: 6.2+ MB

# %%
flights.isnull().sum() # 결측치 확인하고 합계확인
# Out:
# MONTH           0
# DAY             0
# WEEKDAY         0
# AIRLINE         0
# ORG_AIR         0
# DEST_AIR        0
# SCHED_DEP       0
# DEP_DELAY     833
# AIR_TIME     1018
# DIST            0
# SCHED_ARR       0
# ARR_DELAY    1018
# DIVERTED        0
# CANCELLED       0
# dtype: int64

# %%
# 범주형 컬럼의 고유값(class)의 확인
flights['AIRLINE'].unique()
# Out:
# array(['WN', 'UA', 'MQ', 'AA', 'F9', 'EV', 'OO', 'NK', 'US', 'AS', 'DL',
#        'VX', 'B6', 'HA'], dtype=object)

# %%
flights['AIRLINE'].value_counts()
flights['AIRLINE'].value_counts(normalize=True) # 비율!
# Out:
# AIRLINE
# DL    0.181238
# AA    0.152158
# WN    0.143917
# UA    0.133215
# OO    0.112631
# EV    0.100150
# MQ    0.059341
# US    0.027611
# NK    0.025918
# F9    0.022516
# VX    0.016977
# AS    0.013130
# B6    0.009283
# HA    0.001915
# Name: proportion, dtype: float64

# %%
flights['AIRLINE'].nunique() # 고유값이 몇개인지
# Out:
# 14

# %%
flights['WEEKDAY'].value_counts().sort_index()
# Out:
# WEEKDAY
# 1    8720
# 2    8535
# 3    8706
# 4    8659
# 5    8453
# 6    7052
# 7    8367
# Name: count, dtype: int64

# %% [markdown]
# # 기술통계 메소드들을 이용한 데이터 집계
# ## 주요 기술통계 메소드
#
# |함수|설명|
# |-|-|
# |**sum()**|합계|
# |**mean()**|평균|
# |**median()**|중위수|
# |**mode()**|최빈값|
# |**quantile()**|분위수|
# |**std()**|표준편차|
# |**var()**|분산|
# |**count()**|결측치를 제외한 원소 개수|
# |**min()**|최소값|
# |**max()**|최대값|
# |**idxmax()**|최대값 index|
# |**idxmin()**|최소값 index|
# |**unique()**|고유값|
# |**nunique()**|고유값의 개수|
#
# <center><b style='font-size:1.2em'>cf) value_counts()는 Series에만 사용할 수 있다.</b></center>

# %% [markdown]
# - DataFrame에 위의 기술 통계 메소드들을 적용할 경우 **컬럼별로 계산한다.**
# - sum(), mode(), max(), min(), unique(), nunique(), count()는 **문자열에 적용가능하다.**
#     - idxmax(), idxmin() 는 문자열 컬럼에 사용할 수 없다. (문자열의 경우 넘파이의 argmax(), argmin() 함수를 사용한다.)

# %% [markdown]
# - **공통 매개변수**
#     - skipna=True(기본값)
#         - 결측치(NA)를 포함해서 계산할지 여부 설정.
#         - True가 기본값으로 결측치(NA)를 제외하고 처리한다.
#         - 결측치 제외하지 않으려면 skipna=False로 설정하는데 결측치가 있으면 결과는 결측치가 된다.
#     - axis
#         - DataFrame에 적용할 때 계산방향을 설정
#             - 0 또는 'index' (기본값): 컬럼 방향으로 집계
#             - 1 또는 'columns': 행 방향으로 집계

# %%
flights.mean(numeric_only=True)
flights.mean(axis=1, numeric_only=True) # 행단위로 계산할 때 사용
# Out:
# 0        394.818182
# 1        342.000000
# 2        323.727273
# 3        437.636364
# 4        506.090909
#             ...
# 58487    293.000000
# 58488    409.909091
# 58489    376.909091
# 58490    230.090909
# 58491    241.000000
# Length: 58492, dtype: float64

# %%
flights['AIRLINE'].count()
# Out:
# 58492

# %%
# flights['AIRLINE'].idmax() # 이건 안되지만
import numpy as np
np.argmax(flights['AIRLINE']) # 이건됨
# Out:
# 0

# %% [markdown]
# ## aggregate(func, axis=0, \*args, \*\*kwargs) 또는 agg(func, axis=0, \*args, \*\*kwargs)
# - DataFrame, Series의 메소드로 **집계결과를 다양한 형태로 묶어서 볼 때** 사용한다.
#     - **사용자 정의 집계메소드를 사용할 때도 편리하다.**
# - **매개변수**
#     - func
#         - 집계 함수 지정
#             - 함수명/함수리스트 (문자열)
#                 - 판다스 제공 집계메소드들은 문자열로, 사용자정의 집계함수는 함수 객체로 전달
#             - Dictionary : {'집계할컬럼' : 집계함수, ... }
#                 - 컬럼별로 다른 집계를 할 경우
#     - axis
#         - DataFrame에 적용할 때 0 방향으로 계산할 지 1 방향으로 계산할지 설정
#             - 0 또는 'index' (기본값): 컬럼 방향으로 집계
#             - 1 또는 'columns': 행 방향으로 집계
#     - \*args, \*\*kwargs
#         - 함수에 전달할 매개변수.
#         - 집계함수는 첫번째 매개변수로 Series를 받는다. 그 이외의 매개변수가 있는 경우.

# %%
flights["ARR_DELAY"].min(), flights["ARR_DELAY"].max()
# Out:
# (-60.0, 1185.0)

# %%
flights["ARR_DELAY"].aggregate(["min","max"])
# Out:
# min     -60.0
# max    1185.0
# Name: ARR_DELAY, dtype: float64

# %%
# flights["ARR_DELAY"].mean(skipna=False) # 결측치를 포함하여 계산
# flights["ARR_DELAY"].agg("mean",skipna=False) # mean 메소드에 skipna파라미터 값을 전달.
flights["ARR_DELAY"].agg(["mean","sum"], skipna=False)
# Out:
# mean   NaN
# sum    NaN
# Name: ARR_DELAY, dtype: float64

# %%
# 컬럼별로 다른 집계
# key: 컬럼명, value: 집계함수(들)
d={
    "DEP_DELAY":"sum",
    "ARR_DELAY":["min","max"]
    
}
flights.agg(d)
# Out:
#      DEP_DELAY  ARR_DELAY
# sum   629705.0        NaN
# min        NaN      -60.0
# max        NaN     1185.0

# %%
# DEP_DELAY	ARR_DELAY의 평균, 표준 편차
import pandas as pd
fly=pd.read_csv("data/flights.csv")
fly[["DEP_DELAY","ARR_DELAY"]].agg(["mean",'std'])
# Out:
#       DEP_DELAY  ARR_DELAY
# mean  10.921192   5.812315
# std   36.146210  38.411948

# %%
fly
# Out:
#        MONTH  DAY  WEEKDAY AIRLINE ORG_AIR DEST_AIR  SCHED_DEP  DEP_DELAY
# 0          1    1        4      WN     LAX      SLC       1625       58.0  \
# 1          1    1        4      UA     DEN      IAD        823        7.0
# 2          1    1        4      MQ     DFW      VPS       1305       36.0
# 3          1    1        4      AA     DFW      DCA       1555        7.0
# 4          1    1        4      WN     LAX      MCI       1720       48.0
# ...      ...  ...      ...     ...     ...      ...        ...        ...
# 58487     12   31        4      AA     SFO      DFW        515        5.0
# 58488     12   31        4      F9     LAS      SFO       1910       13.0
# 58489     12   31        4      OO     SFO      SBA       1846       -6.0
# 58490     12   31        4      WN     MSP      ATL        525       39.0
# 58491     12   31        4      OO     SFO      BOI        859        5.0
#
#        AIR_TIME  DIST  SCHED_ARR  ARR_DELAY  DIVERTED  CANCELLED
# ...

# %%
flights.describe()
# Out:
#               MONTH           DAY       WEEKDAY     SCHED_DEP     DEP_DELAY
# count  58492.000000  58492.000000  58492.000000  58492.000000  57659.000000  \
# mean       6.220646     15.702096      3.926862   1387.984836     10.921192
# std        3.358484      8.760846      1.995777    482.810792     36.146210
# min        1.000000      1.000000      1.000000      5.000000    -24.000000
# 25%        3.000000      8.000000      2.000000   1000.000000     -4.000000
# 50%        6.000000     16.000000      4.000000   1353.000000     -1.000000
# 75%        9.000000     23.000000      6.000000   1805.000000     10.000000
# max       12.000000     31.000000      7.000000   2359.000000   1194.000000
#
#            AIR_TIME          DIST     SCHED_ARR     ARR_DELAY      DIVERTED
# count  57474.000000  58492.000000  58492.000000  57474.000000  58492.000000  \
# mean     115.928576    872.900072   1549.399832      5.812315      0.002342
# ...

# %%
flights.select_dtypes(exclude="object").agg(['count','mean','std','min','median','max'])
# Out:
#                MONTH           DAY       WEEKDAY     SCHED_DEP     DEP_DELAY
# count   58492.000000  58492.000000  58492.000000  58492.000000  57659.000000  \
# mean        6.220646     15.702096      3.926862   1387.984836     10.921192
# std         3.358484      8.760846      1.995777    482.810792     36.146210
# min         1.000000      1.000000      1.000000      5.000000    -24.000000
# median      6.000000     16.000000      4.000000   1353.000000     -1.000000
# max        12.000000     31.000000      7.000000   2359.000000   1194.000000
#
#             AIR_TIME          DIST     SCHED_ARR     ARR_DELAY      DIVERTED
# count   57474.000000  58492.000000  58492.000000  57474.000000  58492.000000  \
# mean      115.928576    872.900072   1549.399832      5.812315      0.002342
# std        71.679591    624.996805    518.599952     38.411948      0.048340
# min         8.000000     67.000000      1.000000    -60.000000      0.000000
# ...

# %%
# 사용자 정의 집계함수
### 첫번째 파라미터: 통계량을 구할 Series
### 추가적으로 더 필요한것
### 반환값: 계산한 통계량


# 최대값과 최소값의 차이 
def max_min_diff(columns:pd.Series):
    max_v= columns.max()
    min_v= columns.min()
    return max_v - min_v

# %%
fly[["DEP_DELAY","ARR_DELAY"]].agg(["max","min",max_min_diff])
# Out:
#               DEP_DELAY  ARR_DELAY
# max              1194.0     1185.0
# min               -24.0      -60.0
# max_min_diff     1218.0     1245.0

# %%
# IQR값 계산하는 사용자 정의 집계함수를 만들어서 
# '"DEP_DELAY","ARR_DELAY" 컬럼에  IQR값을 조회
# IQR InterQuartilerandge # 3분위 - 1분위
a=fly["DEP_DELAY"].quantile(q=[0.25,0.5,0.75])
a
print(a.values)
def iqr(columns:pd.Series):
    result=columns.quantile(q=[0.25,0.5,0.75]).values
    return result[2]-result[0]
b=fly[["DEP_DELAY","ARR_DELAY"]].agg(iqr).to_frame().rename(columns={0: "interquartile range"})
b.transpose()
# Dataframe 의 열을 변경하려면 객체.rename(colunms= {바꿀 문자: 바뀔문자})
# 행열 전환하려면 객체.transpose()
# Series 대입
# r1,r2=flights["DEP_DELAY"].quantile(q=[0.25,0.75])
# print(r1,r2)
# Out:
# [-4. -1. 10.]
#                      DEP_DELAY  ARR_DELAY
# interquartile range       14.0       21.0

# %% [markdown]
# # Groupby
# - 특정 열을 기준으로 같은 값을 가지는 행끼리 묶어서 group화 한다.
# - **~~ 별 집계를 할 때** 사용한다. (성별, 직급별, 등급별 ...)
#     - Group으로 묶을 기준 열은 범주형타입(category)을 사용한다.
# - **구문**
#     - `DF.groupby('그룹으로묶을기준컬럼')`
#         - DataFrameGroupby 객체를 반환한다.
#         - DataFrameGroupby 객체는 어떤 행끼리 묶여있는지 정보를 가진다. 이 객체의 집계함수를 사용하면 그룹별 집계를 할 수 있다.
#             - `DataFrameGroupby객체['집계할 컬럼'].집계함수()`
#         - groupby에 여러개의 컬럼을 기준으로 나눌 경우 리스트에 묶어서 전달한다.
#         - 집계할 컬럼이 여러개인 경우 리스트로 묶어준다.
#     - 집계함수
#         - 기술통계 함수들
#         - agg()/aggregate()
#             - 여러 다른 집계함수 호출시(여러 집계를 같이 볼경우)
#             - 사용자정의 집계함수 호출시
#             - 컬럼별로 다른 집계함수들을 호출할 경우

# %%
# 객체.groupby("그룹으로 묶을 기준 컬럼")
# 예시 객체.groupby("AIRFLANE") 비행기 14개 그룹으로 나누겠다!

# %%
fly
# Out:
#        MONTH  DAY  WEEKDAY AIRLINE ORG_AIR DEST_AIR  SCHED_DEP  DEP_DELAY
# 0          1    1        4      WN     LAX      SLC       1625       58.0  \
# 1          1    1        4      UA     DEN      IAD        823        7.0
# 2          1    1        4      MQ     DFW      VPS       1305       36.0
# 3          1    1        4      AA     DFW      DCA       1555        7.0
# 4          1    1        4      WN     LAX      MCI       1720       48.0
# ...      ...  ...      ...     ...     ...      ...        ...        ...
# 58487     12   31        4      AA     SFO      DFW        515        5.0
# 58488     12   31        4      F9     LAS      SFO       1910       13.0
# 58489     12   31        4      OO     SFO      SBA       1846       -6.0
# 58490     12   31        4      WN     MSP      ATL        525       39.0
# 58491     12   31        4      OO     SFO      BOI        859        5.0
#
#        AIR_TIME  DIST  SCHED_ARR  ARR_DELAY  DIVERTED  CANCELLED
# ...

# %%
# groupby() 메소드를 이용해서 나누기(group별로 묶어주기)
r=fly.groupby("AIRLINE")
fly.isnull().sum()
# AIRLINE의 값이 같은 행끼리 같은 그룹으로 묶어준다
# print(type(r))
# r.groups # 어떤 그룹으로 묶였는지 알려줌
### AA': [3, 6, 8, 15, 26,............... 640, 652, ...]
# re=pd.DataFrame(r.groups).transpose()
# Out:
# MONTH           0
# DAY             0
# WEEKDAY         0
# AIRLINE         0
# ORG_AIR         0
# DEST_AIR        0
# SCHED_DEP       0
# DEP_DELAY     833
# AIR_TIME     1018
# DIST            0
# SCHED_ARR       0
# ARR_DELAY    1018
# DIVERTED        0
# CANCELLED       0
# dtype: int64

# %%
# AIRLINE 별 각 컬럼 들의 평균 값
fly.groupby("AIRLINE").mean(numeric_only=True)
# numeric_only=True로 설정하면, 수치형 열의 평균 값만 계산합니다.
# 따라서, 평균값을 계산하는데 필요하지 않은 문자열과 같은 열이 있을 경우 에러를 방지
# Out:
#             MONTH        DAY   WEEKDAY    SCHED_DEP  DEP_DELAY    AIR_TIME
# AIRLINE
# AA       6.661461  15.570562  3.986966  1340.140449  11.274057  144.259404  \
# AS       6.197917  15.247396  3.941406  1418.269531   1.808594  147.845052
# B6       6.368324  15.788214  4.040516  1512.924494  14.287823  209.412963
# DL       6.277332  15.721158  3.913310  1426.563154   7.242450  115.334187
# EV       6.003926  15.866166  3.927450  1415.510413   9.092625   68.964016
# F9       6.401670  15.914958  4.007593  1407.121488  14.310398  127.592337
# HA       5.508929  15.526786  3.750000   959.419643   2.571429  338.288288
# MQ       5.970614  15.598963  3.902622  1432.251801  11.094323   61.318346
# NK       6.602243  15.680739  4.006596  1336.634565  19.514401  135.736878
# OO       6.134791  15.651943  3.923345  1426.486794   9.662279   76.010272
# UA       6.322510  15.697510  3.871535  1357.970739  16.210485  155.650521
# ...

# %%
# AIRLINE 별 도착지연시간의 평균
fly.groupby("AIRLINE")["ARR_DELAY"].mean().to_frame()
# Out:
#          ARR_DELAY
# AIRLINE
# AA        5.542661
# AS       -0.833333
# B6        8.692593
# DL        0.339691
# EV        7.034580
# F9       13.630651
# HA        4.972973
# MQ        6.860591
# NK       18.436070
# OO        7.593463
# UA        7.765755
# US        1.681105
# VX        5.348884
# WN        6.397353

# %%
# AIRLINE 별 출발/ 도착 지연시간의 평균
fly.groupby("AIRLINE")[["ARR_DELAY","DEP_DELAY"]].mean()
# Out:
#          ARR_DELAY  DEP_DELAY
# AIRLINE
# AA        5.542661  11.274057
# AS       -0.833333   1.808594
# B6        8.692593  14.287823
# DL        0.339691   7.242450
# EV        7.034580   9.092625
# F9       13.630651  14.310398
# HA        4.972973   2.571429
# MQ        6.860591  11.094323
# NK       18.436070  19.514401
# OO        7.593463   9.662279
# UA        7.765755  16.210485
# US        1.681105   4.361355
# VX        5.348884   8.918946
# WN        6.397353  12.639366

# %%
flights.groupby("AIRLINE")[['DEP_DELAY',"ARR_DELAY"]].agg(["mean","std"]).sort_values(by=('ARR_DELAY', 'mean'))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[42], line 1
# ----> 1 flights.groupby("AIRLINE")[['DEP_DELAY',"ARR_DELAY"]].agg(["mean","std"]).sort_values(by=('ARR_DELAY', 'mean'))
#
# NameError: name 'flights' is not defined

# %%
# AIRLINE 별 출발/ 도착 지연시간의 평균,표준편차
fly.groupby("AIRLINE")[["DEP_DELAY","ARR_DELAY"]].agg(["mean","std"])
# 멀티 인덱스여서 컬럼에 어떤것인지 묶어서 알려줘야하며 튜플로 묶어줘야함
# a.sort_values("ARR_DELAY")
# b.transpose()
# Out:
#          DEP_DELAY             ARR_DELAY
#               mean        std       mean        std
# AIRLINE
# AA       11.274057  40.787806   5.542661  43.323160
# AS        1.808594  29.543702  -0.833333  31.168354
# B6       14.287823  36.863416   8.692593  40.221718
# DL        7.242450  29.759377   0.339691  32.299471
# EV        9.092625  34.582917   7.034580  36.682336
# F9       14.310398  51.773844  13.630651  53.030912
# HA        2.571429  33.880743   4.972973  37.528283
# MQ       11.094323  31.159293   6.860591  36.324657
# NK       19.514401  46.484632  18.436070  48.727259
# OO        9.662279  33.413767   7.593463  35.331344
# UA       16.210485  44.834336   7.765755  46.405935
# US        4.361355  24.550930   1.681105  27.030227
# VX        8.918946  31.782085   5.348884  33.747675
# WN       12.639366  30.506549   6.397353  32.610666

# %%
# 요일(WEEKDAY)별 출발 지연 시간의 평균
fly.groupby("WEEKDAY")["DEP_DELAY"].mean().to_frame()
# Out:
#          DEP_DELAY
# WEEKDAY
# 1        12.546447
# 2        10.256383
# 3        10.582201
# 4        11.505021
# 5        10.789574
# 6         9.333669
# 7        11.142371

# %% [markdown]
# ##  복수열 기준 그룹핑
# - 두개 이상의 열을 그룹으로 묶을 수 있다.
# - groupby의 매개변수에 그룹으로 묶을 컬럼들의 이름을 리스트로 전달한다.

# %%
# 항공사, 요일별 도착지연 시간의 평균
# == 항공사와 요일 컬럼의 값이 같은 행끼리 묶겠다.
fly.groupby(["AIRLINE","WEEKDAY"])["ARR_DELAY"].mean().to_frame()
# Series.to_frame() :Series를 DataFrame으로 변환
# Out:
#                  ARR_DELAY
# AIRLINE WEEKDAY
# AA      1         9.135772
#         2         3.009053
#         3         2.979561
#         4         6.474771
#         5         6.743017
# ...                    ...
# WN      3         5.370518
#         4         8.524800
#         5         6.722781
#         6         2.449692
#         7         6.398601
#
# [98 rows x 1 columns]

# %%
fly.head(2)
# Out:
#    MONTH  DAY  WEEKDAY AIRLINE ORG_AIR DEST_AIR  SCHED_DEP  DEP_DELAY
# 0      1    1        4      WN     LAX      SLC       1625       58.0  \
# 1      1    1        4      UA     DEN      IAD        823        7.0
#
#    AIR_TIME  DIST  SCHED_ARR  ARR_DELAY  DIVERTED  CANCELLED
# 0      94.0   590       1905       65.0         0          0
# 1     154.0  1452       1333      -13.0         0          0

# %%
# 출발공항(ORG_AIR),도착공항(DEST_ORG) 별 출발 지연시간(DEP_DELAY)의 평균
fly.groupby(["ORG_AIR","DEST_AIR"])["DEP_DELAY"].mean().to_frame()
# Out:
#                   DEP_DELAY
# ORG_AIR DEST_AIR
# ATL     ABE        9.612903
#         ABQ        7.062500
#         ABY       22.473684
#         ACY        7.166667
#         AEX       11.000000
# ...                     ...
# SFO     SNA        8.483051
#         STL       25.100000
#         SUN       17.700000
#         TUS       14.200000
#         XNA       -3.000000
#
# [1130 rows x 1 columns]

# %%
# 출발공항(ORG_AIR),도착공항(DEST_ORG) 별 출발 지연시간(DEP_DELAY)의 최대,최소/최대 최소의 차이
fly.groupby(["ORG_AIR","DEST_AIR"])["DEP_DELAY"].agg(max_min_diff).to_frame()
# Out:
#                   DEP_DELAY
# ORG_AIR DEST_AIR
# ATL     ABE           178.0
#         ABQ            81.0
#         ABY           179.0
#         ACY            22.0
#         AEX           136.0
# ...                     ...
# SFO     SNA           315.0
#         STL           159.0
#         SUN            74.0
#         TUS           165.0
#         XNA             4.0
#
# [1130 rows x 1 columns]

# %% [markdown]
# ## Group 별 집계결과에서 특정 조건의 항목만 조회
# - Groupby 집계 후 boolean indexing 처리한다.

# %%
fly.head(2)
# Out:
#    MONTH  DAY  WEEKDAY AIRLINE ORG_AIR DEST_AIR  SCHED_DEP  DEP_DELAY
# 0      1    1        4      WN     LAX      SLC       1625       58.0  \
# 1      1    1        4      UA     DEN      IAD        823        7.0
#
#    AIR_TIME  DIST  SCHED_ARR  ARR_DELAY  DIVERTED  CANCELLED
# 0      94.0   590       1905       65.0         0          0
# 1     154.0  1452       1333      -13.0         0          0

# %%
#항공사별 취소건수의 총합이 100건 이상인 항공사
 #개복잡함
#
fly.groupby("AIRLINE")["CANCELLED"].sum()[fly.groupby("AIRLINE")["CANCELLED"].sum()>=100].to_frame()

a=fly.groupby("AIRLINE")["CANCELLED"].sum()
a[a>=100].to_frame()
# Out:
#          CANCELLED
# AIRLINE
# AA             154
# EV             146
# MQ             152
# OO             142

# %% [markdown]
# # 사용자 정의 집계함수를 만들어 적용
#
# ## 사용자 정의 집계 함수 정의
# - Parameter(매개변수)
#     1. Series 또는 DataFrame을 받을 매개변수(필수)
#     2. 필요한 값을 받을 매개변수를 선언한다. (선택)

# %% [markdown]
# # TODO

# %%
# 1. data/diamonds.csv 를 읽어 DataFrame 생성
dia=pd.read_csv("data/diamonds.csv")
dia
# Out:
#        carat        cut color clarity  depth  table  price     x     y     z
# 0       0.23      Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1       0.21    Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2       0.23       Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3       0.29    Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4       0.31       Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75
# ...      ...        ...   ...     ...    ...    ...    ...   ...   ...   ...
# 53935   0.72      Ideal     D     SI1   60.8   57.0   2757  5.75  5.76  3.50
# 53936   0.72       Good     D     SI1   63.1   55.0   2757  5.69  5.75  3.61
# 53937   0.70  Very Good     D     SI1   62.8   60.0   2757  5.66  5.68  3.56
# 53938   0.86    Premium     H     SI2   61.0   58.0   2757  6.15  6.12  3.74
# 53939   0.75      Ideal     D     SI2   62.2   55.0   2757  5.83  5.87  3.64
#
# [53940 rows x 10 columns]

# %%
# 2. 1에서 생성한 DataFrame의 정보 조회
#     - 배열의 shape조회
#     - DataFrame에 대한 정보조회
#     - 상/하위 5개 행 조회
#     - 결측치 확인
#     - 배열의 shape조회
dia.shape
# Out:
# (53940, 10)

# %%
#     - DataFrame에 대한 정보조회
dia.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 53940 entries, 0 to 53939
# Data columns (total 10 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   carat    53940 non-null  float64
#  1   cut      53940 non-null  object
#  2   color    53940 non-null  object
#  3   clarity  53940 non-null  object
#  4   depth    53940 non-null  float64
#  5   table    53940 non-null  float64
#  6   price    53940 non-null  int64
#  7   x        53940 non-null  float64
#  8   y        53940 non-null  float64
#  9   z        53940 non-null  float64
# dtypes: float64(6), int64(1), object(3)
# memory usage: 4.1+ MB

# %%
#     - 상/하위 5개 행 조회
dia.head()
# Out:
#    carat      cut color clarity  depth  table  price     x     y     z
# 0   0.23    Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1   0.21  Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2   0.23     Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3   0.29  Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4   0.31     Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75

# %%
dia.tail()
# Out:
#        carat        cut color clarity  depth  table  price     x     y     z
# 53935   0.72      Ideal     D     SI1   60.8   57.0   2757  5.75  5.76  3.50
# 53936   0.72       Good     D     SI1   63.1   55.0   2757  5.69  5.75  3.61
# 53937   0.70  Very Good     D     SI1   62.8   60.0   2757  5.66  5.68  3.56
# 53938   0.86    Premium     H     SI2   61.0   58.0   2757  6.15  6.12  3.74
# 53939   0.75      Ideal     D     SI2   62.2   55.0   2757  5.83  5.87  3.64

# %%
#     - 결측치 확인
dia.isnull().sum()
# Out:
# carat      0
# cut        0
# color      0
# clarity    0
# depth      0
# table      0
# price      0
# x          0
# y          0
# z          0
# dtype: int64

# %%
#     - 배열의 shape조회

# %%
# 3. carat, price, depth의 합계, 평균, 최대, 최소 조회
dia[['carat','price','depth']].agg(['sum','mean','max','min'])
#
# Out:
#             carat         price         depth
# sum   43040.87000  2.121352e+08  3.330763e+06
# mean      0.79794  3.932800e+03  6.174940e+01
# max       5.01000  1.882300e+04  7.900000e+01
# min       0.20000  3.260000e+02  4.300000e+01

# %%
# 4. price는 최대, 최소, color는 고유값의 개수를 조회
dia.agg({"price":["max","min"],"color":'nunique'})
# Out:
#            price  color
# max      18823.0    NaN
# min        326.0    NaN
# nunique      NaN    7.0

# %%
# 5. cut의 고유값별 개수를 조회
dia["cut"].nunique()
# Out:
# 5

# %%
# 6. cut별 가격 평균 조회
dia.groupby('cut')['price'].sum().to_frame()
# Out:
#               price
# cut
# Fair        7017600
# Good       19275009
# Ideal      74513487
# Premium    63221498
# Very Good  48107623

# %%
# 7. cut별 가격 평균중 4000이상만 조회
me=dia.groupby('cut')['price'].mean()
me[me>=4000].to_frame()
# Out:
#                price
# cut
# Fair     4358.757764
# Premium  4584.257704

# %%
# 8. clarity별 carat 평균과 표준편차 조회
dia.groupby('clarity')['carat'].agg(['mean','std'])
# Out:
#              mean       std
# clarity
# I1       1.283846  0.632436
# IF       0.505123  0.313433
# SI1      0.850482  0.449652
# SI2      1.077648  0.516653
# VS1      0.727158  0.423529
# VS2      0.763935  0.446292
# VVS1     0.503321  0.299557
# VVS2     0.596202  0.359697

# %%
# 9. cut과 color 별로 가격은 평균을 carat은 최대값을 조회 
re=dia.groupby(['cut','color']).agg({'price':"mean","carat":"max"})
re.rename(columns={'price':'price_mean','carat':'carat_max'})
# Out:
#                   price_mean  carat_max
# cut       color
# Fair      D      4291.061350       3.40
#           E      3682.312500       2.04
#           F      3827.003205       2.58
#           G      4239.254777       2.60
#           H      5135.683168       4.13
#           I      4685.445714       3.02
#           J      4975.655462       5.01
# Good      D      3405.382175       2.04
#           E      3423.644159       3.00
#           F      3495.750275       2.67
#           G      4123.482204       2.80
#           H      4276.254986       3.01
#           I      5078.532567       3.01
#           J      4574.172638       3.00
# Ideal     D      2629.094566       2.75
#           E      2597.550090       2.28
#           F      3374.939362       2.45
#           G      3720.706388       2.54
#           H      3889.334831       3.50
#           I      4451.970377       3.22
#           J      4918.186384       3.01
# Premium   D      3631.292576       2.57
# ...

# %%
# 10. 9번 문제의 결과에서 가격의 평균이 5000이상이고 carat의 최대값이 3이상인 결과만 조회
re=re.rename(columns={'price':'price_mean','carat':'carat_max'})
re[(re['price_mean']>=5000) & (re['carat_max']>=3)]  #  갓벽하다 ...rename(columns={ 자주 이용하자})
# Out:
#                   price_mean  carat_max
# cut       color
# Fair      H      5135.683168       4.13
# Good      I      5078.532567       3.01
# Premium   H      5216.706780       3.24
#           I      5946.180672       4.01
#           J      6294.591584       4.01
# Very Good I      5255.879568       4.00

# %%
ref=a.query("price >= 5000 and carat >=3") # 다른방식!!!
ref.transpose()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[46], line 1
# ----> 1 ref=a.query("price >= 5000 and carat >=3") # 다른방식!!!
#       2 ref.transpose()
#
# NameError: name 'a' is not defined
