# %% [markdown]
# # 참고문서들
# - [django 공식문서](https://docs.djangoproject.com/en/4.2/)
#
# - [Mozilla django](https://developer.mozilla.org/ko/docs/Learn/Server-side/Django)
#
# - [Inflearn - 나의 첫 Django 앱 만들기](https://www.inflearn.com/course/%EB%82%98%EC%9D%98-%EC%B2%AB-django-%EC%95%B1-%EB%A7%8C%EB%93%A4%EA%B8%B0?utm_source=google&utm_medium=cpc&utm_campaign=06.general_python&utm_content=django_dsa&utm_term=&gad=1&gclid=CjwKCAjwo7iiBhAEEiwAsIxQEQKVTeARJSNMFyjMvHNgGESDmFKiVmqpcjJMrBg5Wy7LgVZ3m8bl0BoCURcQAvD_BwE#curriculum)
#
# - [Django 강좌](https://076923.github.io/posts/Python-Django-1/)

# %% [markdown]
# # TODO 리스트 예제
# - https://realpython.com/django-todo-lists/#step-8-use-your-django-to-do-list-app
# - https://www.youtube.com/watch?v=4RWFvXDUmjo
# - https://www.youtube.com/watch?v=llbtoQTt4qw

# %% [markdown]
# # 블로그 만들기 예제
# - https://djangocentral.com/building-a-blog-application-with-django/
# - https://justdjango.com/blog/build-a-blog-with-django
# - https://medium.com/geekculture/create-a-blog-with-django-60f529f1d8b6
# - https://nachwon.github.io/django-1-setting/
# - https://www.youtube.com/watch?v=jS4fLseF_cs

# %% [markdown]
# # 인스타그램 만들기 예제
# - https://www.youtube.com/watch?v=M8UPyeF5DfM

# %% [markdown]
# # 대쉬보드 만들기 예제
# - https://www.youtube.com/watch?v=19YTQ26h14c
# - https://www.youtube.com/watch?v=TcnWEQMT3_A
# - https://www.youtube.com/watch?v=PjJ2pQLUDng

# %% [markdown]
# # Vue.js 연동 예제
# - https://velog.io/@corner3499/Django-7-Todo-%EC%95%B1-%EC%84%A4%EA%B3%84-Vue-Django-%EC%97%B0%EB%8F%99

# %% [markdown]
# # 배포 예제
# - https://www.youtube.com/watch?v=1s0kNMDYdGk
# - https://www.youtube.com/watch?v=5rjhJRyu8s8
