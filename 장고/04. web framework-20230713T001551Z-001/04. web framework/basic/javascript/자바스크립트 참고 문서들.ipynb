# %% [markdown]
# # 참고 문서들

# %% [markdown]
# - [모던 자바스크립트](https://ko.javascript.info/)
# - [이룸코딩 - 자바스크립트 기초](https://www.youtube.com/watch?v=Nx-NJcefgIg&list=PLI33CnBTx2MZGD7zAQ810_B8dDU_E8gaq)
# - [JavaScript Tutorial](https://www.javascripttutorial.net/)
# - [Mozilla JavaScript](https://developer.mozilla.org/en-US/docs/Learn/JavaScript)
