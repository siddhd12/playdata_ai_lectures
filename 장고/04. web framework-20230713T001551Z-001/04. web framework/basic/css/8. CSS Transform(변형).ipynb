# %% [markdown]
# # [Transform(변형)](https://seulbinim.github.io/WSA/transform.html#transform-%EC%86%8D%EC%84%B1)

# %% [markdown]
# ## translate
#
# ```css
# /* 예시 */
# div { transform : translate(50px, 50px) ; }
# div { transform : translateX(50px) ; }
# div { transform : translateY(50px) ; }
# ```

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## scale
#
# ```css
# /* 예시 */
# div { transform : scale(0.5, 0.5) ; }
# div { transform : scaleX(0.5) ; }
# div { transform : scaleY(0.5) ; }
# ```

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## rotate
#
# ```css
# /* 예시 */
# div { transform : rotate(45deg) ; }
# ```

# %% [markdown]
# ![image.png](data:image/png;base64,...)
