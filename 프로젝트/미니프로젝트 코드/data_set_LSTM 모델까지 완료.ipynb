# %%
# !pip install pykrx
# Out:
# Requirement already satisfied: pykrx in c:\users\playdata\anaconda3\envs\ml\lib\site-packages (1.0.44)
# Requirement already satisfied: requests in c:\users\playdata\anaconda3\envs\ml\lib\site-packages (from pykrx) (2.31.0)
# Requirement already satisfied: pandas in c:\users\playdata\anaconda3\envs\ml\lib\site-packages (from pykrx) (2.0.0)
# Requirement already satisfied: datetime in c:\users\playdata\anaconda3\envs\ml\lib\site-packages (from pykrx) (5.1)
# Requirement already satisfied: numpy in c:\users\playdata\anaconda3\envs\ml\lib\site-packages (from pykrx) (1.23.5)
# Requirement already satisfied: xlrd in c:\users\playdata\anaconda3\envs\ml\lib\site-packages (from pykrx) (2.0.1)
# Requirement already satisfied: deprecated in c:\users\playdata\anaconda3\envs\ml\lib\site-packages (from pykrx) (1.2.14)
# Requirement already satisfied: multipledispatch in c:\users\playdata\anaconda3\envs\ml\lib\site-packages (from pykrx) (1.0.0)
# Requirement already satisfied: matplotlib in c:\users\playdata\anaconda3\envs\ml\lib\site-packages (from pykrx) (3.7.1)
# Requirement already satisfied: zope.interface in c:\users\playdata\anaconda3\envs\ml\lib\site-packages (from datetime->pykrx) (6.0)
# Requirement already satisfied: pytz in c:\users\playdata\anaconda3\envs\ml\lib\site-packages (from datetime->pykrx) (2023.3)
# Requirement already satisfied: wrapt<2,>=1.10 in c:\users\playdata\anaconda3\envs\ml\lib\site-packages (from deprecated->pykrx) (1.14.1)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\playdata\anaconda3\envs\ml\lib\site-packages (from matplotlib->pykrx) (1.0.7)
# Requirement already satisfied: cycler>=0.10 in c:\users\playdata\anaconda3\envs\ml\lib\site-packages (from matplotlib->pykrx) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\playdata\anaconda3\envs\ml\lib\site-packages (from matplotlib->pykrx) (4.39.3)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\playdata\anaconda3\envs\ml\lib\site-packages (from matplotlib->pykrx) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\playdata\anaconda3\envs\ml\lib\site-packages (from matplotlib->pykrx) (23.1)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\playdata\anaconda3\envs\ml\lib\site-packages (from matplotlib->pykrx) (9.5.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\playdata\anaconda3\envs\ml\lib\site-packages (from matplotlib->pykrx) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\playdata\anaconda3\envs\ml\lib\site-packages (from matplotlib->pykrx) (2.8.2)
# Requirement already satisfied: tzdata>=2022.1 in c:\users\playdata\anaconda3\envs\ml\lib\site-packages (from pandas->pykrx) (2023.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\playdata\anaconda3\envs\ml\lib\site-packages (from requests->pykrx) (3.1.0)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\playdata\anaconda3\envs\ml\lib\site-packages (from requests->pykrx) (2.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\playdata\anaconda3\envs\ml\lib\site-packages (from requests->pykrx) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\playdata\anaconda3\envs\ml\lib\site-packages (from requests->pykrx) (2022.12.7)
# Requirement already satisfied: six>=1.5 in c:\users\playdata\anaconda3\envs\ml\lib\site-packages (from python-dateutil>=2.7->matplotlib->pykrx) (1.16.0)
# Requirement already satisfied: setuptools in c:\users\playdata\anaconda3\envs\ml\lib\site-packages (from zope.interface->datetime->pykrx) (68.0.0)

# %%
from pykrx import stock
from pykrx import bond

import matplotlib.pyplot as plt
import os
import pandas as pd
import numpy as np

from datetime import datetime, timedelta

# %%
# ticker 조회
tickers = stock.get_market_ticker_list()
print(tickers)
# Out:
# ['095570', '006840', '027410', '282330', '138930', '001460', '001465', '001040', '079160', '00104K', '000120', '011150', '011155', '001045', '097950', '097955', '000590', '012030', '016610', '005830', '000990', '139130', '001530', '000210', '001880', '000215', '375500', '37550L', '37550K', '007340', '004840', '155660', '069730', '017940', '365550', '383220', '007700', '114090', '078930', '006360', '001250', '007070', '078935', '012630', '039570', '089470', '294870', '009540', '267250', '267270', '322000', '042670', '267260', '329180', '097230', '014790', '003580', '204320', '060980', '011200', '082740', '035000', '003560', '175330', '234080', '001060', '001067', '001065', '096760', '105560', '432320', '002380', '344820', '009070', '009440', '119650', '092220', '003620', '016380', '001390', '033180', '001940', '025000', '092230', '000040', '044450', '030200', '033780', '058850', '058860', '093050', '003550', '034220', '051900', '051905', '373220', '003555', '032640', '011070', '066570', '066575', '037560', '051910', '051915', '079550', '006260', '010120', '000680', '229640', '108320', '001120', '108670', '108675', '383800', '38380K', '023150', '035420', '181710', '400760', '005940', '005945', '338100', '034310', '008260', '004250', '004255', '456040', '010060', '178920', '005490', '010950', '010955', '034120', '005090', '001380', '004060', '001770', '002360', '009160', '123700', '025530', '034730', '011790', '018670', '001740', '006120', '006125', '210980', '068400', '395400', '302440', '326030', '402340', '361610', '100090', '03473K', '096770', '096775', '001510', '001515', '285130', '28513K', '017670', '000660', '003570', '064960', '100840', '036530', '005610', '011810', '077970', '071970', '002820', '084870', '002710', '069260', '002900', '024070', '037270', '000500', '000860', '035250', '011420', '002100', '009450', '267290', '012320', '000050', '214390', '012610', '009140', '013580', '012200', '012205', '002140', '010130', '002240', '009290', '017040', '017900', '037710', '030610', '339770', '007690', '005320', '001140', '002720', '083420', '014530', '014280', '014285', '008870', '001570', '002990', '002995', '011780', '011785', '214330', '001210', '073240', '092440', '000270', '024110', '013700', '004540', '004545', '001260', '008350', '008355', '004270', '003920', '003925', '025860', '005720', '005725', '002350', '002355', '251270', '090350', '090355', '000320', '000325', '006280', '005250', '005257', '004370', '072710', '058730', '030210', '023590', '145210', '019680', '019685', '006370', '008060', '00806K', '353200', '35320K', '000490', '008110', '005750', '006570', '001680', '001685', '084690', '084695', '128820', '117580', '016710', '003540', '003547', '003545', '009190', '014160', '047040', '009320', '003090', '069620', '000430', '006340', '006345', '003220', '024890', '002880', '000300', '012800', '015230', '001070', '006650', '001440', '084010', '001790', '001795', '001130', '003490', '003495', '005880', '003830', '016090', '069460', '118000', '192080', '012510', '004830', '004835', '024900', '145720', '002150', '460850', '460860', '001230', '023450', '004140', '007590', '005960', '005965', '026960', '002210', '102260', '000640', '170900', '028100', '282690', '001520', '001527', '084670', '082640', '001525', '008970', '092780', '049770', '018500', '006040', '030720', '014820', '014825', '163560', '004890', '002690', '000020', '000150', '000157', '241560', '034020', '000155', '336260', '33626K', '33626L', '016740', '192650', '024090', '003160', '092200', '377190', '013570', '210540', '115390', '032350', '089860', '330590', '000400', '023530', '020150', '280360', '004000', '286940', '004990', '00499K', '005300', '005305', '011170', '071840', '027740', '357430', '001080', '088980', '094800', '138040', '090370', '017180', '009900', '012690', '005360', '204210', '009680', '009580', '009200', '033920', '008420', '025560', '007120', '396690', '357250', '085620', '006800', '00680K', '006805', '002840', '268280', '107590', ...

# %%
# 특정 ticker에 해당하는 종목명 조회
for ticker in tickers:
    event_name = stock.get_market_ticker_name(ticker)
    if event_name in '삼성전자':
        print(f"ticker: {ticker}, 종목명: {event_name}")
# Out:
# ticker: 005930, 종목명: 삼성전자

# %%
# 특정 종목에 대한 1년치 주가 기록 추출 2018년~2023년
df = stock.get_market_ohlcv("20180711", "20230711", "005930")
len(df)
# Out:
# 1234

# %%
df.reset_index(inplace=True)

# %%
# 타임 스탬프 확인
df['날짜'][0]
# Out:
# Timestamp('2018-07-11 00:00:00')

# %%
df.head(6)
# Out:
#           날짜     시가     고가     저가     종가       거래량          거래대금   등락률
# 0 2018-07-11  46400  46450  45400  46000  11224077  515223640592 -0.65
# 1 2018-07-12  45900  46250  45450  45500  11828104  541036686150 -1.09
# 2 2018-07-13  45800  46500  45750  46500  11543389  533402245850  2.20
# 3 2018-07-16  46800  46800  46000  46050   7678719  356079488741 -0.97
# 4 2018-07-17  46150  46200  45600  45850   8892953  408291768123 -0.43
# 5 2018-07-18  46700  47200  46450  46550  10952645  511712248050  1.53

# %%
df.tail(10)
# Out:
#              날짜     시가     고가     저가     종가       거래량           거래대금   등락률
# 1224 2023-06-28  72600  72700  72000  72700   8783093   635516679700  0.14
# 1225 2023-06-29  73100  73400  72400  72400  12229967   891731369446 -0.41
# 1226 2023-06-30  72500  72700  71700  72200  11694765   844353820176 -0.28
# 1227 2023-07-03  72700  73200  72600  73000  10722181   782251095800  1.11
# 1228 2023-07-04  73400  73600  72900  73000  10214350   747624440200  0.00
# 1229 2023-07-05  73000  73300  71900  72000  12310610   889637363400 -1.37
# 1230 2023-07-06  71900  72400  71500  71600  14777667  1061491980700 -0.56
# 1231 2023-07-07  71100  71400  69800  69900  17308877  1215404338500 -2.37
# 1232 2023-07-10  70000  70400  69200  69500  11713926   816772079400 -0.57
# 1233 2023-07-11  70200  71500  70100  71500  12177392   863673766650  2.88

# %% [markdown]
# # minmax scailing 하기

# %%
from sklearn.preprocessing import MinMaxScaler,StandardScaler

def scaling_standard(dataframe):
    scaler = StandardScaler()
    scale_cols = ['시가','고가', '저가', '종가', '거래량','거래대금','등락률']
    df_scaled = scaler.fit_transform(dataframe[scale_cols])
    df_scaled = pd.DataFrame(df_scaled)
    df_scaled.columns = scale_cols
    for i in df_scaled.columns:
        df[i]=df_scaled[i]
    return df

# %%
scaling_standard(df)
# Out:
#              날짜        시가        고가        저가        종가       거래량      거래대금
# 0    2018-07-11 -1.076539 -1.108372 -1.117096 -1.108039 -0.557094 -0.753284  \
# 1    2018-07-12 -1.114861 -1.123622 -1.113238 -1.146470 -0.481509 -0.711008
# 2    2018-07-13 -1.122525 -1.104560 -1.090093 -1.069608 -0.517137 -0.723511
# 3    2018-07-16 -1.045882 -1.081686 -1.070806 -1.104196 -1.000743 -1.013932
# 4    2018-07-17 -1.095700 -1.127434 -1.101666 -1.119568 -0.848799 -0.928418
# ...         ...       ...       ...       ...       ...       ...       ...
# 1229 2023-07-05  0.962147  0.938873  0.927361  0.890377 -0.421131 -0.140067
# 1230 2023-07-06  0.877841  0.870250  0.896501  0.859632 -0.112415  0.141398
# 1231 2023-07-07  0.816527  0.794003  0.765347  0.728966  0.204328  0.393476
# 1232 2023-07-10  0.732220  0.717755  0.719058  0.698222 -0.495797 -0.259406
# 1233 2023-07-11  0.747549  0.801628  0.788492  0.851946 -0.437801 -0.182590
#
#            등락률
# 0    -0.439072
# 1    -0.715858
# 2     1.353747
# 3    -0.640371
# 4    -0.300679
# ...        ...
# 1229 -0.891995
# 1230 -0.382457
# 1231 -1.521054
# 1232 -0.388747
# 1233  1.781507
#
# [1234 rows x 8 columns]

# %%
df.drop(columns='날짜',inplace=True)

# %%
df
# Out:
#             시가        고가        저가        종가       거래량      거래대금       등락률
# 0    -1.076539 -1.108372 -1.117096 -1.108039 -0.557094 -0.753284 -0.439072
# 1    -1.114861 -1.123622 -1.113238 -1.146470 -0.481509 -0.711008 -0.715858
# 2    -1.122525 -1.104560 -1.090093 -1.069608 -0.517137 -0.723511  1.353747
# 3    -1.045882 -1.081686 -1.070806 -1.104196 -1.000743 -1.013932 -0.640371
# 4    -1.095700 -1.127434 -1.101666 -1.119568 -0.848799 -0.928418 -0.300679
# ...        ...       ...       ...       ...       ...       ...       ...
# 1229  0.962147  0.938873  0.927361  0.890377 -0.421131 -0.140067 -0.891995
# 1230  0.877841  0.870250  0.896501  0.859632 -0.112415  0.141398 -0.382457
# 1231  0.816527  0.794003  0.765347  0.728966  0.204328  0.393476 -1.521054
# 1232  0.732220  0.717755  0.719058  0.698222 -0.495797 -0.259406 -0.388747
# 1233  0.747549  0.801628  0.788492  0.851946 -0.437801 -0.182590  1.781507
#
# [1234 rows x 7 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1234 entries, 0 to 1233
# Data columns (total 7 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   시가      1234 non-null   float64
#  1   고가      1234 non-null   float64
#  2   저가      1234 non-null   float64
#  3   종가      1234 non-null   float64
#  4   거래량     1234 non-null   float64
#  5   거래대금    1234 non-null   float64
#  6   등락률     1234 non-null   float64
# dtypes: float64(7)
# memory usage: 67.6 KB

# %% [markdown]
# # sequence data 만들기

# %%
def sequnce_data(dataset):
    feature=dataset.copy() 
    feature=feature[:-1] # 현재 data로 -> 다음날 종가를 예측 
    target=dataset.copy()
    target=target['종가'][1:]
    return feature.values,target.values
####
#     날짜	   시가	 고가	   저가     종가	 거래량	  거래대금	   등락률
#	2018-07-11	46400	46450	45400	46000	11224077	515223640592	-0.65 -> 7/12 일 종가 45500가 타겟이되게 지정
#	2018-07-12	45900	46250	45450	45500	11828104	541036686150	-1.09

# %%
feature, target=sequnce_data(df)

# %%
feature.shape, target.shape
# Out:
# ((1233, 7), (1233,))

# %%
target[4]
# Out:
# -1.0657645664703577

# %%
feature[:2]
# Out:
# array([[-1.0765394 , -1.10837233, -1.11709555, -1.10803874, -0.55709397,
#         -0.75328431, -0.43907212],
#        [-1.11486058, -1.12362183, -1.11323809, -1.14646981, -0.48150901,
#         -0.71100754, -0.71585823]])

# %% [markdown]
# # window size 만들기

# %%
len(feature)
# Out:
# 1233

# %%
len(target)
# Out:
# 1233

# %%
def window_data(feature,target,num):
    window=num
    seq_feature=[]
    seq_target=[]
    for i in range(len(target)-window+1):
            seq_feature.append(feature[i:i+window])
            seq_target.append(target[i+window-1])
    return seq_feature,seq_target

# %%
seq_feature,seq_target=window_data(feature,target,5)

# %%
seq_feature[0]
# Out:
# array([[-1.0765394 , -1.10837233, -1.11709555, -1.10803874, -0.55709397,
#         -0.75328431, -0.43907212],
#        [-1.11486058, -1.12362183, -1.11323809, -1.14646981, -0.48150901,
#         -0.71100754, -0.71585823],
#        [-1.12252481, -1.10455995, -1.0900933 , -1.06960767, -0.51713684,
#         -0.72351127,  1.35374675],
#        [-1.04588246, -1.0816857 , -1.07080597, -1.10419564, -1.00074255,
#         -1.01393163, -0.64037112],
#        [-1.09569999, -1.1274342 , -1.10166569, -1.11956806, -0.84879931,
#         -0.92841802, -0.30067911]])

# %%
seq_target[0]
# Out:
# -1.0657645664703577

# %%
len(seq_feature)
# Out:
# 1229

# %%
type(seq_feature)
# Out:
# list

# %%
seq_feature[0],seq_target[0]
# Out:
# (array([[-1.0765394 , -1.10837233, -1.11709555, -1.10803874, -0.55709397,
#          -0.75328431, -0.43907212],
#         [-1.11486058, -1.12362183, -1.11323809, -1.14646981, -0.48150901,
#          -0.71100754, -0.71585823],
#         [-1.12252481, -1.10455995, -1.0900933 , -1.06960767, -0.51713684,
#          -0.72351127,  1.35374675],
#         [-1.04588246, -1.0816857 , -1.07080597, -1.10419564, -1.00074255,
#          -1.01393163, -0.64037112],
#         [-1.09569999, -1.1274342 , -1.10166569, -1.11956806, -0.84879931,
#          -0.92841802, -0.30067911]]),
#  -1.0657645664703577)

# %% [markdown]
# # dataset 만들기

# %%
import torch
from torch.utils.data import Dataset
class MakeDataset(Dataset):

    def __init__(self,feature,target):
        super().__init__()
        self.feature = feature
        self.target = target
        self.feature=torch.Tensor(self.feature)
        self.target=torch.Tensor(self.target)
    def __len__(self):
        return self.feature.shape[0]

    def __getitem__(self, idx:int):
        return self.feature[idx],self.target[idx]

# %%
dataset_dummy= MakeDataset(seq_feature,seq_target)
# Out:
# C:\Users\Playdata\AppData\Local\Temp\ipykernel_19604\1320404065.py:9: UserWarning: Creating a tensor from a list of numpy.ndarrays is extremely slow. Please consider converting the list to a single numpy.ndarray with numpy.array() before converting to a tensor. (Triggered internally at ..\torch\csrc\utils\tensor_new.cpp:248.)
#   self.feature=torch.Tensor(self.feature)

# %%
type(dataset_dummy.feature)
# Out:
# torch.Tensor

# %%
dataset_dummy.feature.shape,dataset_dummy.target.shape
# 전체 데이터 갯수,한개에 5개의 데이터가 있고 데이터안에 7개 컬럼이있음
# Out:
# (torch.Size([1229, 5, 7]), torch.Size([1229]))

# %%
dataset_dummy.feature[0].shape
# Out:
# torch.Size([5, 7])

# %% [markdown]
# # Dataloader 만들기

# %%
from torch.utils.data import DataLoader

# %%
data_loader = torch.utils.data.DataLoader(dataset_dummy,batch_size=10,shuffle=False,drop_last=True)

# %%
# data set 나오는거 확인
next(iter(data_loader))[0].shape
next(iter(data_loader))[1].shape
# batch,data갯수,컬럼 갯수
# Out:
# torch.Size([10])

# %%
7개를 embedding_size 에 넣어준다

# %%
device = 'cuda' if torch.cuda.is_available() else 'cpu'
device
# Out:
# 'cpu'

# %% [markdown]
# # LSTM 모델 만들기

# %%
input_dim
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[46], line 1
# ----> 1 input_dim
#
# NameError: name 'input_dim' is not defined

# %%
import numpy as np
import torch
import torch.nn as nn
import torch.optim as optim
class LSTM_Model(torch.nn.Module):
    def __init__(self,input_dim,device='cpu',hidden_dim=64,layer_dim=3,output_layer=1):
        super().__init__()
        self.device = device
        self.layer_dim=layer_dim
        self.hidden_dim=hidden_dim
        self.lstm = nn.LSTM(input_size=input_dim,hidden_size=hidden_dim,num_layers=self.layer_dim, dropout=0.3, bidirectional=True)
        self.linear = nn.Linear(hidden_dim, output_layer, bias=True)
        self.relu = nn.ReLU()
    def forward(self, x):
        scaler = 2 if self.lstm.bidirectional == True else 1 # Bi-LSTM(2), LSTM(1)
        # 초기화
        hidden_state = torch.zeros(self.layer_dim*scaler, x.size(0),
                                  self.hidden_dim, requires_grad=True).to(self.device)
        cell_state = torch.zeros(self.layer_dim*scaler, x.size(0),
                                  self.hidden_dim, requires_grad=True).to(self.device)
        out, (hidden_state, cell_state) =self.lstm(x,(hidden_state,cell_state))
        h = hidden_state[-1]
        h=self.relu(h)
        predict = self.linear(h)
        
        return predict

# %%
model = LSTM_Model(len(dataset_dummy)).to(device)

# %%
model
# Out:
# LSTM_Model(
#   (lstm): LSTM(1229, 64, num_layers=3, dropout=0.3, bidirectional=True)
#   (linear): Linear(in_features=64, out_features=1, bias=True)
#   (relu): ReLU()
# )

# %%
model(next(iter(data_loader))[0].to(device)).shape
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[55], line 1
# ----> 1 model(next(iter(data_loader))[0].to(device)).shape
#
# File ~\anaconda3\envs\ml\lib\site-packages\torch\nn\modules\module.py:1501, in Module._call_impl(self, *args, **kwargs)
#    1496 # If we don't have any hooks, we want to skip the rest of the logic in
#    1497 # this function, and just call forward.
#    1498 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1499         or _global_backward_pre_hooks or _global_backward_hooks
#    1500         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1501     return forward_call(*args, **kwargs)
#    1502 # Do not call functions when jit is used
#    1503 full_backward_hooks, non_full_backward_hooks = [], []
#
# Cell In[52], line 21, in LSTM_Model.forward(self, x)
#      17 hidden_state = torch.zeros(self.layer_dim*scaler, x.size(0),
#      18                           self.hidden_dim, requires_grad=True).to(self.device)
#      19 cell_state = torch.zeros(self.layer_dim*scaler, x.size(0),
#      20                           self.hidden_dim, requires_grad=True).to(self.device)
# ---> 21 out, (hidden_state, cell_state) =self.lstm(x,(hidden_state,cell_state))
#      22 h = hidden_state[-1]
#      23 h=self.relu(h)
#
# File ~\anaconda3\envs\ml\lib\site-packages\torch\nn\modules\module.py:1501, in Module._call_impl(self, *args, **kwargs)
#    1496 # If we don't have any hooks, we want to skip the rest of the logic in
#    1497 # this function, and just call forward.
#    1498 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1499         or _global_backward_pre_hooks or _global_backward_hooks
#    1500         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1501     return forward_call(*args, **kwargs)
#    1502 # Do not call functions when jit is used
#    1503 full_backward_hooks, non_full_backward_hooks = [], []
#
# File ~\anaconda3\envs\ml\lib\site-packages\torch\nn\modules\rnn.py:810, in LSTM.forward(self, input, hx)
#     806     # Each batch of the hidden state should match the input sequence that
#     807     # the user believes he/she is passing in.
#     808     hx = self.permute_hidden(hx, sorted_indices)
# --> 810 self.check_forward_args(input, hx, batch_sizes)
#     811 if batch_sizes is None:
#     812     result = _VF.lstm(input, hx, self._flat_weights, self.bias, self.num_layers,
#     813                       self.dropout, self.training, self.bidirectional, self.batch_first)
#
# File ~\anaconda3\envs\ml\lib\site-packages\torch\nn\modules\rnn.py:730, in LSTM.check_forward_args(self, input, hidden, batch_sizes)
#     725 def check_forward_args(self,  # type: ignore[override]
#     726                        input: Tensor,
#     727                        hidden: Tuple[Tensor, Tensor],
#     728                        batch_sizes: Optional[Tensor],
#     729                        ):
# --> 730     self.check_input(input, batch_sizes)
#     731     self.check_hidden_size(hidden[0], self.get_expected_hidden_size(input, batch_sizes),
#     732                            'Expected hidden[0] size {}, got {}')
#     733     self.check_hidden_size(hidden[1], self.get_expected_cell_size(input, batch_sizes),
#     734                            'Expected hidden[1] size {}, got {}')
#
# File ~\anaconda3\envs\ml\lib\site-packages\torch\nn\modules\rnn.py:218, in RNNBase.check_input(self, input, batch_sizes)
#     214     raise RuntimeError(
#     215         'input must have {} dimensions, got {}'.format(
#     216             expected_input_dim, input.dim()))
#     217 if self.input_size != input.size(-1):
# --> 218     raise RuntimeError(
#     219         'input.size(-1) must be equal to input_size. Expected {}, got {}'.format(
#     220             self.input_size, input.size(-1)))
#
# RuntimeError: input.size(-1) must be equal to input_size. Expected 1229, got 7

# %% [markdown]
# # 학습시 사용할 분리 셋 만들기

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test= train_test_split(seq_feature, seq_target,test_size=0.3, random_state=0)
