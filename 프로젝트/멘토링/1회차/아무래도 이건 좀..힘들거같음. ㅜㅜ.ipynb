# %%
import os
import pandas as pd

# %%
os.getcwd()
# Out:
# 'C:\\Users\\Playdata\\Desktop\\멘토링\\1회차'

# %%
file_path=f'C:/Users/Playdata/Desktop/멘토링/1회차/input_sejong/BTAA0001.txt'

# %%
with open(file_path, 'r',encoding='utf-8') as file:
    length=file.readline()
    print(length)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 with open(file_path, 'r',encoding='utf-8') as file:
#       2     length=file.readline()
#       3     print(length)
#
# NameError: name 'file_path' is not defined

# %%
if length='\n'
    length=='':
        break

# %%
\n

# %%
dict=nlp_dict(folder_path)

# %%
len(dict.concat_df)
# Out:
# 217184

# %%
true_list=[]
false_list=[true_list.append(i) if '+' in i else None for i in dict.concat_df[0]]

# %%
true_list
# Out:
# ['실내\t/SS + 실내/NNG',
#  '값비싼\t/SS + 값비싸/VA + ㄴ/ETM',
#  '우리\t/SS + 우리/NP',
#  '중국\t/SS + 중국/NNP',
#  '가족\t/SS + 가족/NNG',
#  '여성의\t/SS + 여성/NNG + 의/JKG',
#  '가족\t/SS + 가족/NNG',
#  '그러나\t/SS + 그러나/MAJ',
#  '대학\t/SS + 대학/NNG',
#  '평기리는\t/SS + 평기리/NNP + 는/JX',
#  '이런\t/SS + 이런/MM',
#  '세침흡인\t/SS + 세침/NNG + 흡인/NNG',
#  '이\t/SS + 이/MM',
#  '물체가\t/SS + 물체/NNG + 가/JKS',
#  '밤에\t/SS + 밤/NNG + 에/JKB',
#  '낙상\t/SS + 낙상/NNG',
#  '상설할인매장은\t/SS + 상설/NNG + 할인/NNG + 매장/NNG + 은/JX',
#  '평균적으로\t/SS + 평균/NNG + 적/XSN + 으로/JKB',
#  '부상\t/SS + 부상/NNG',
#  '아직\t/SS + 아직/MAG',
#  '재미로\t/SS + 재미/NNG + 로/JKB',
#  '물속\t/SS + 물속/NNG',
#  '물속\t/SS + 물속/NNG',
#  '평범한\t/SS + 평범/XR + 하/XSA + ㄴ/ETM',
#  '신문을\t/SS + 신문/NNG + 을/JKO',
#  '값싸고\t/SS + 값싸/VA + 고/EC',
#  '88,\t/SS + 88/SN + ,/SP',
#  '발\t/SS + 발/NNG',
#  '손때\t/SS + 손때/NNG',
#  '어린이에\t/SS + 어린이/NNG + 에/JKB',
#  '자기만\t/SS + 자기/NP + 만/JX',
#  '우리의\t/SS + 우리/NP + 의/JKG',
#  '우리\t/SS + 우리/NP',
#  '폭넓은\t/SS + 폭넓/VA + 은/ETM',
#  '우리\t/SS + 우리/NP',
# ...

# %%
for i in true_list:
    if i !=None:
        print(i)
# Out:
# 실내	/SS + 실내/NNG
# 값비싼	/SS + 값비싸/VA + ㄴ/ETM
# 우리	/SS + 우리/NP
# 중국	/SS + 중국/NNP
# 가족	/SS + 가족/NNG
# 여성의	/SS + 여성/NNG + 의/JKG
# 가족	/SS + 가족/NNG
# 그러나	/SS + 그러나/MAJ
# 대학	/SS + 대학/NNG
# 평기리는	/SS + 평기리/NNP + 는/JX
# 이런	/SS + 이런/MM
# 세침흡인	/SS + 세침/NNG + 흡인/NNG
# 이	/SS + 이/MM
# 물체가	/SS + 물체/NNG + 가/JKS
# 밤에	/SS + 밤/NNG + 에/JKB
# 낙상	/SS + 낙상/NNG
# 상설할인매장은	/SS + 상설/NNG + 할인/NNG + 매장/NNG + 은/JX
# 평균적으로	/SS + 평균/NNG + 적/XSN + 으로/JKB
# 부상	/SS + 부상/NNG
# 아직	/SS + 아직/MAG
# 재미로	/SS + 재미/NNG + 로/JKB
# 물속	/SS + 물속/NNG
# 물속	/SS + 물속/NNG
# 평범한	/SS + 평범/XR + 하/XSA + ㄴ/ETM
# 신문을	/SS + 신문/NNG + 을/JKO
# 값싸고	/SS + 값싸/VA + 고/EC
# 88,	/SS + 88/SN + ,/SP
# 발	/SS + 발/NNG
# 손때	/SS + 손때/NNG
# 어린이에	/SS + 어린이/NNG + 에/JKB
# 자기만	/SS + 자기/NP + 만/JX
# 우리의	/SS + 우리/NP + 의/JKG
# 우리	/SS + 우리/NP
# 폭넓은	/SS + 폭넓/VA + 은/ETM
# 우리	/SS + 우리/NP
# 내가	/SS + 내/NP + 가/JKS
# 내가	/SS + 내/NP + 가/JKS
# 외국에서는	/SS + 외국/NNG + 에서/JKB + 는/JX
# 어른들은	/SS + 어른/NNG + 들/XSN + 은/JX
# 연인들은	/SS + 연인/NNG + 들/XSN + 은/JX
# 휴가를	/SS + 휴가/NNG + 를/JKO
# ...

# %%
""생명교육은    "/SS + 생명/NNG + 교육/NNG + 은/JX"

# %%
true_list#   + 가 속한거
# Out:
# [None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  7,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
# ...

# %%
dict.concat_df[0]
# Out:
# 0                                 1993/06/08
# 1                             #%# 1993/06/08
# 2                                         19
# 3                                     #%# 19
# 4                                       엠마누엘
#                         ...
# 15004                                    꾸준히
# 15005                                    독자를
# 15006                                   확보하고
# 15007                                    있다.
# 15008    #%# 이 책들 중 일부는 지금도 꾸준히 독자를 확보하고 있다.
# Name: 0, Length: 217184, dtype: object

# %%
# Out:
# 204198

# %%
sentence_freq=[]
eojeol_freq=[]

# %%
sentence_freq=[] # 문장 넣을거 
eojeol_freq=[]
for i in dict.concat_df[0]:
    if '#%#' in i:
        sentence_freq.append(i)
    else:
        eojeol_freq.append(i)

# %%
len(sentence_freq)
# Out:
# 14524

# %%
len(set(sentence_freq))
# Out:
# 12986

# %%
num=0
eojeol_list=[]
for i in eojeol_freq:
    num+=1
    eojeol_list.append(i)

# %%
eojeol_list=(set(eojeol_list))
eojeol_list
# Out:
# {"지수'로",
#  "반대'니",
#  '김용만)이',
#  '양탄자',
#  '우원건축)',
#  "'전의를",
#  '생명교육은\t/SS + 생명/NNG + 교육/NNG + 은/JX',
#  '금융계',
#  '원한다.',
#  '만족도가',
#  '증설',
#  '임명철·62)가',
#  '추론을',
#  '종업원들에게',
#  '즐기라는',
#  '붕괴되지는',
#  '해라는',
#  '생산했다.',
#  '분신',
#  '방지는',
#  '타협해',
#  '법어부터',
#  '20∼30대',
#  '빌려갔다',
#  '바꾸기는',
#  '한쪽으로',
#  '찻상',
#  '암매장할',
#  "'특선'이란",
#  '해태제과',
#  '걷히고',
#  '얽혀들면,',
#  '생각하고,',
#  '설악',
#  '1991/09/05',
#  '찬성하라는',
#  '계절이',
#  "'그렇다'고",
#  '여름밤을',
#  '취해지면',
#  '주변으로부터',
#  '국민',
#  '정신요양원과',
#  '데이비드',
#  '3일까지',
#  '장관이',
#  '기자들로부터',
#  '내면적',
#  '나타내',
#  '살려낸',
#  '비디오를',
#  '건널목',
#  '절도',
#  '건설된',
#  '중심지이다.',
#  '탈',
#  '신탁',
#  '탄생하게',
#  '풀어가기',
#  '침구-이불은',
#  '순전히',
#  '거론해야',
#  '기업인',
#  '7천여만원을',
#  '원인을',
#  '관습과',
#  '귀성준비와',
#  '납품해',
#  '외면하게',
#  '장애자들,',
#  '활성화보다는',
#  '연상하게',
#  '공납금에',
#  '브라운등의',
#  '메아리친다.',
#  '현존-기성',
#  '참가하겠다고',
#  '도움',
#  '선린-우호를',
#  '맘을',
#  '회선이',
#  '일어난다고',
#  '거듭',
#  '악용될',
#  "'정치는",
#  '조정하고',
#  '개각과',
# ...

# %%
folder_list=os.scandir(folder_path)

# %%
df_list=[]
for i in folder_list:
    txt_file=pd.read_table(i,header=None)
    df_list.append(txt_file)
#     num+=1
#     if num==1:
#         break

# %%
len_list=0
for i in num_list:
    len_list+=len(i)
print(len_list)
# Out:
# 217184

# %%
concat_df = pd.concat(num_list)

# %%
len(concat_df)
# Out:
# 217184

# %%
with open(file_path, 'r',encoding='utf-8') as file:
    lines = file.readlines()

# %%
for line_number, line in enumerate(lines, start=1):
    line_length = len(line.strip())
line_length
# Out:
# 0

# %%
fully_sentence
# Out:
# ['#%# 1993/06/08\n',
#  '#%# 19\n',
#  '#%# 엠마누엘 웅가로 / 의상서 실내 장식품으로… 디자인 세계 넓혀\n',
#  '#%# 프랑스의 세계적인 의상 디자이너 엠마누엘 웅가로가 실내 장식용 직물 디자이너로 나섰다.\n',
#  "#%# 웅가로는 침실과 식당, 욕실에서 사용하는 갖가지 직물제품을 디자인해 최근 파리의 갤러리 라파예트백화점에서 '색의 컬렉션'이라는 이름으로 전시회를 열었다.\n",
#  '#%# 목욕가운부터 탁자보, 냅킨, 앞치마까지 그가 디자인한 작품들에서 두드러지는 것은 색의 조화다.\n',
#  '#%# 남미풍의 강렬한 원색끼리의 조화, 수채화 같이 안온한 배색 등 색의 분위기를 강조하는 기하학적 무늬, 꽃무늬 디자인이 주류를 이루고 있다.\n',
#  '#%# 엠마누엘 웅가로는 "실내 장식품을 디자인할 때 옷을 만들 때와는 다른 해방감을 느낀다"고 말한다.\n',
#  '#%# 집은 창작의 원천이라는 그는 옷 못지않게 공간이 주는 미학을 중요시해 왔다.\n',
#  '#%# 매일 욕실에서 1시간 반 이상을 보낸다는 그는 체조와 텔레비전 시청, 식사까지 할 수 있는 욕실이 나와야 한다고 주장할 정도다.\n',
#  "#%# 옷을 만드느라 늘 대하는 천을 실내용품을 위해 다시 디자인하는 것은 '상상력을 마음껏 펼치는 즐거운 놀이'라고 말하는 그는 다른 디자이너들처럼 찻잔, 접시등 식기 디자인까지 활동 폭을 넓혀갈 계획이다.\n",
#  '#%# 1993/06/10\n',
#  '#%# 18\n',
#  '#%# 여름 주방 생활 용품 / 빙수 - 샤베트기… 안방서 더위식힌다\n',
#  '#%# 얼음 대신 쓰는 아이스팩도 인기 / 국산 다양… 성능 외제에 손색 없어\n',
#  '#%# 빙수기, 샤베트기, 얼음 물통 등 여름 주방 생활 용품이 인기다.\n',
#  '#%# 특히 여름철 더위를 식히는데 최고인 빙수를 만드는 기계는 소비자들이 가장 많이 찾고 있는 품목.\n',
# ...

# %%
word_split[0]
# Out:
# '1993/SN '

# %%
morp_list=[]
for i in word_split:
    morp=i.strip().split('//')
#     print(morp)
    morp_list.append(morp)
word_list=[]
for sen in morp_list:
#     print(sen)
    if '' in sen:
        sen_split=['/' if item =='' else item for item in sen]
        word_list.append(sen_split)
    else:
        for i in sen:
            i_split=i.split('/')
            word_list.append(i_split)
print(word_list)
# Out:
# [['1993', 'SN'], ['/', 'SP'], ['06', 'SN'], ['/', 'SP'], ['08', 'SN']]

# %%
morp_list
# Out:
# [['1993/SN'], ['', 'SP'], ['06/SN'], ['', 'SP'], ['08/SN']]

# %%
for i in word_list:
    print(i)
# Out:
# ['1993', 'SN']
# ['/', 'SP']
# ['06', 'SN']
# ['/', 'SP']
# ['08', 'SN']

# %%
word_list=[]

for sen in morp_list:
#     print(sen)
    if '' in sen:
        sen_split=['/' if item =='' else item for item in sen]
        word_list.append(sen_split)
    else:
        for i in sen:
            i_split=i.split('/')
            word_list.append(i_split)
#         print(sen_split)
#     print(type(sen))
#     if '/' in sen:

#         word_list.append(sen.split('/'))

# %%
word_list
# Out:
# [['1993', 'SN'], ['/', 'SP'], ['06', 'SN'], ['/', 'SP'], ['08', 'SN']]

# %%
word_list[0]
# Out:
# [['1993', 'SN']]

# %%
mor_list=[]
for i in word_split:
    morp=i.strip().split('//')
#     print(morp)
    mor_list=['/' if item=="" else item.split('/') for item in morp]
print(mor_list)
# Out:
# [['08', 'SN']]

# %%
morp_list
# Out:
# [['1993/SN'], ['', 'SP'], ['06/SN'], ['', 'SP'], ['08/SN']]

# %%
T=[True if item =="" else False for item in morp_list]
T
# Out:
# [False, False, False, False, False]

# %%
mod
# Out:
# [['1993/SN'], ['', 'SP'], ['06/SN'], ['', 'SP'], ['08/SN']]

# %%
morp_list[1][0]==""
# Out:
# True

# %%
for sen in morp_list:
    pre=[item if item != "" else "/" for item in sen]
    print(pre)
# Out:
# ['1993/SN']
# ['/', 'SP']
# ['06/SN']
# ['/', 'SP']
# ['08/SN']

# %%
original_list = ["", "sp"]

# 리스트 내부의 빈 문자열을 슬래시로 변경
modified_list = [item if item != "" else "/" for item in original_list]

print(modified_list)
# Out:
# ['/', 'sp']

# %%
with open(file_path, 'r',encoding='utf-8') as file:
    lines = file.readlines()

# %%
a=df[0][2]

# %%
a_split=a.split('\t')

# %%
b=a_split[1]

# %%
import time

start_time = time.time()  # 코드 실행 시작 시간 기록

# 실행 시간을 측정하려는 코드
# 예를 들어, 어떤 작업을 수행하는 코드를 여기에 작성

end_time = time.time()

# %%
eojeol_sentece[2].split('\t')
# Out:
# ['"생명교육은', '"/SS + 생명/NNG + 교육/NNG + 은/JX']
